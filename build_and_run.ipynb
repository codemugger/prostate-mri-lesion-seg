# %% [markdown]
# Install MONAI Deploy App SDK and dependencies

# %%
# %pip install -r prostate_mri_lesion_seg_app/requirements.txt

# %% [markdown]
# Download models and test data

# %%
# Download the following folder (ProstateX-0004) and place in test-data/
# https://drive.google.com/drive/folders/1besSncSLlbeiv7UWveRJoOYQXOzu3JkU?usp=drive_link

# Download the following folder of models and place in prostate_lesion_seg_app/models
# https://drive.google.com/drive/folders/1EpjrlzEdV7CcaCYqGTIEzOapamP4Ag6M?usp=drive_link

# %%
import os 
os.getcwd()
# Out:
# '/home/anson/work/research-contributions/prostate-mri-lesion-seg'

# %% [markdown]
# Test application locally (non-containerized)

# %%
# %%bash

# ./scripts/test_local.sh -i test-data/ProstateX-0004/ -o output/ -m models/

# %% [markdown]
# Run Batch Script instead (ownself created)

# %%
# %%bash
#
# # -r          = resume mode (skip cases that already have output, safe after crash)
# # --cooldown  = seconds to pause between cases (lets CPU cool down, prevents BSOD)
# #               default 30s; increase if still crashing, decrease if stable
# bash ./scripts/test_batch.sh -i test-data/ -o output_charlie/ -m models/ -r --cooldown 10
# Out:
# *** RESUME mode: skipping cases that already have output files ***
# *** RESUME mode: existing audit CSV will be appended to       ***
# Batch processing 40 patients under: test-data/
# Writing per-patient outputs under: output_charlie/
# Using model directory: models/
# Cooldown between cases: 10s
# Audit CSV: output_charlie//batch_audit_log.csv
#
# ========================================
# [1/40] Patient: 20201208_1debe8d041264ee1f4f8
#   Input:  test-data//20201208_1debe8d041264ee1f4f8/
#   Output: output_charlie//20201208_1debe8d041264ee1f4f8
#   Running on GPU...
# [2026-04-28 15:15:19,972] [INFO] (root) - Parsed args: Namespace(log_level=None, input=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20201208_1debe8d041264ee1f4f8'), output=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20201208_1debe8d041264ee1f4f8'), model=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/models'), workdir=None, argv=['/home/anson/work/research-contributions/prostate-mri-lesion-seg/scripts/../prostate_mri_lesion_seg_app', '-i', 'test-data//20201208_1debe8d041264ee1f4f8/', '-o', 'output_charlie//20201208_1debe8d041264ee1f4f8', '-m', 'models/'])
# [2026-04-28 15:15:19,981] [INFO] (root) - AppContext object: AppContext(input_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20201208_1debe8d041264ee1f4f8, output_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20201208_1debe8d041264ee1f4f8, model_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/models, workdir=)
# [2026-04-28 15:15:19,981] [INFO] (app.AIProstateLesionSegApp) - App input and output path: /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20201208_1debe8d041264ee1f4f8, /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20201208_1debe8d041264ee1f4f8
# [info] [gxf_executor.cpp:210] Creating context
# [warning] [gxf_extension_manager.cpp:132] Unable to load extension from 'libgxf_bayer_demosaic.so' (error: libnppicc.so.11: cannot open shared object file: No such file or directory)
# [info] [gxf_executor.cpp:1595] Loading extensions from configs...
# [info] [gxf_executor.cpp:1741] Activating Graph...
# [info] [gxf_executor.cpp:1771] Running Graph...
# [info] [gxf_executor.cpp:1773] Waiting for completion...
# [info] [gxf_executor.cpp:1774] Graph execution waiting. Fragment:
# [info] [greedy_scheduler.cpp:190] Scheduling 15 entities
# [2026-04-28 15:15:20,074] [INFO] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - No or invalid input path from the optional input port: None
# [2026-04-28 15:15:20,178] [WARNING] (pydicom) - The value length (20) exceeds the maximum length of 16 allowed for VR SH.
# The value length (20) exceeds the maximum length of 16 allowed for VR SH.
# [2026-04-28 15:15:20,182] [INFO] (root) - Finding series for Selection named: highb
# [2026-04-28 15:15:20,183] [INFO] (root) - Searching study, : 1.2.826.0.1.3680043.8.498.12901500232701184823954887614973439393
#   # of series: 1
# [2026-04-28 15:15:20,183] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.65095442527324190824817798398862971343
# [2026-04-28 15:15:20,183] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:15:20,183] [INFO] (root) -     Series attribute Modality value: MR
# [2026-04-28 15:15:20,183] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '^(?!.*adc)(?!.*(?:localizer|survey))(?:(?=.*tracew?)|(?=.*dwi)|(?=.*diff)|(?=.*calc)|(?=.*compute[dr]?)|(?=.*(?:focus|muse).*b[0-9])).*'
# [2026-04-28 15:15:20,183] [INFO] (root) -     Series attribute SeriesDescription value: t1_vibe_opp-in_tra_caipi4_bh_320_W
# [2026-04-28 15:15:20,183] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:15:20,183] [INFO] (root) - This series does not match the selection conditions.
# [2026-04-28 15:15:20,184] [INFO] (root) - Finding series for Selection named: adc
# [2026-04-28 15:15:20,185] [INFO] (root) - Searching study, : 1.2.826.0.1.3680043.8.498.12901500232701184823954887614973439393
#   # of series: 1
# [2026-04-28 15:15:20,185] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.65095442527324190824817798398862971343
# [2026-04-28 15:15:20,185] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:15:20,185] [INFO] (root) -     Series attribute Modality value: MR
# [2026-04-28 15:15:20,185] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '^(?!.*(?:localizer|survey))(?=.*adc).*'
# [2026-04-28 15:15:20,185] [INFO] (root) -     Series attribute SeriesDescription value: t1_vibe_opp-in_tra_caipi4_bh_320_W
# [2026-04-28 15:15:20,185] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:15:20,185] [INFO] (root) - This series does not match the selection conditions.
# [2026-04-28 15:15:20,188] [INFO] (root) - Finding series for Selection named: t2
# [2026-04-28 15:15:20,189] [INFO] (root) - Searching study, : 1.2.826.0.1.3680043.8.498.12901500232701184823954887614973439393
#   # of series: 1
# [2026-04-28 15:15:20,190] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.65095442527324190824817798398862971343
# [2026-04-28 15:15:20,190] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:15:20,190] [INFO] (root) -     Series attribute Modality value: MR
# [2026-04-28 15:15:20,190] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '^(?!.*(?:obl|oblq|oblique|obq|cor|sag|pelvis|whole[_ ]?pelvis|wholepelvis|tirm|stir|space|localizer|survey|t1|\\+c|adc|dwi|diff|tracew?|_fs_|_fs\\b|\\bfs_|\\bfs\\b))(?=.*t2)(?=.*(?:tra|\\bax\\b|axial|^ax[_ ]|_ax[_ ]|AX[_ ])).*'
# [2026-04-28 15:15:20,190] [INFO] (root) -     Series attribute SeriesDescription value: t1_vibe_opp-in_tra_caipi4_bh_320_W
# [2026-04-28 15:15:20,190] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:15:20,191] [INFO] (root) - This series does not match the selection conditions.
# Exception occurred for operator: 'series_to_vol_HIGHB'
# Traceback (most recent call last):
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 60, in compute
#     image = self.convert_to_image(study_selected_series_list)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 67, in convert_to_image
#     raise ValueError("Missing expected input 'study_selected_series_list'")
# ValueError: Missing expected input 'study_selected_series_list'
# Exception occurred for operator: 'series_to_vol_ADC'
# Traceback (most recent call last):
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 60, in compute
#     image = self.convert_to_image(study_selected_series_list)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 67, in convert_to_image
#     raise ValueError("Missing expected input 'study_selected_series_list'")
# ValueError: Missing expected input 'study_selected_series_list'
# Exception occurred for operator: 'series_to_vol_T2'
# Traceback (most recent call last):
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 60, in compute
#     image = self.convert_to_image(study_selected_series_list)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 67, in convert_to_image
#     raise ValueError("Missing expected input 'study_selected_series_list'")
# ValueError: Missing expected input 'study_selected_series_list'
# [info] [greedy_scheduler.cpp:369] Scheduler stopped: Some entities are waiting for execution, but there are no periodic or async entities to get out of the deadlock.
# [info] [greedy_scheduler.cpp:398] Scheduler finished.
# [info] [gxf_executor.cpp:1783] Graph execution deactivating. Fragment:
# [info] [gxf_executor.cpp:1784] Deactivating Graph...
# [info] [gxf_executor.cpp:1787] Graph execution finished. Fragment:
# [info] [gxf_executor.cpp:229] Destroying context
#   DONE (exit 0)
#   Status: FAIL_EMPTY_OUTPUT  [missing: t2,adc,highb]
#   Reason: No output files produced at all - most likely every series selector rejected the input (check SeriesDescription regexes in prostate_mri_lesion_seg_app/app.py).
#   Cooldown 10s before next case...
# ========================================
# [2/40] Patient: 20210406_c184b117e662d27b3ded
#   Input:  test-data//20210406_c184b117e662d27b3ded/
#   Output: output_charlie//20210406_c184b117e662d27b3ded
#   Running on GPU...
# [2026-04-28 15:15:41,408] [INFO] (root) - Parsed args: Namespace(log_level=None, input=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20210406_c184b117e662d27b3ded'), output=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20210406_c184b117e662d27b3ded'), model=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/models'), workdir=None, argv=['/home/anson/work/research-contributions/prostate-mri-lesion-seg/scripts/../prostate_mri_lesion_seg_app', '-i', 'test-data//20210406_c184b117e662d27b3ded/', '-o', 'output_charlie//20210406_c184b117e662d27b3ded', '-m', 'models/'])
# [2026-04-28 15:15:41,413] [INFO] (root) - AppContext object: AppContext(input_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20210406_c184b117e662d27b3ded, output_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20210406_c184b117e662d27b3ded, model_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/models, workdir=)
# [2026-04-28 15:15:41,413] [INFO] (app.AIProstateLesionSegApp) - App input and output path: /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20210406_c184b117e662d27b3ded, /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20210406_c184b117e662d27b3ded
# [info] [gxf_executor.cpp:210] Creating context
# [warning] [gxf_extension_manager.cpp:132] Unable to load extension from 'libgxf_bayer_demosaic.so' (error: libnppicc.so.11: cannot open shared object file: No such file or directory)
# [info] [gxf_executor.cpp:1595] Loading extensions from configs...
# [info] [gxf_executor.cpp:1741] Activating Graph...
# [info] [gxf_executor.cpp:1771] Running Graph...
# [info] [gxf_executor.cpp:1773] Waiting for completion...
# [info] [gxf_executor.cpp:1774] Graph execution waiting. Fragment:
# [info] [greedy_scheduler.cpp:190] Scheduling 15 entities
# [2026-04-28 15:15:41,484] [INFO] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - No or invalid input path from the optional input port: None
# [2026-04-28 15:15:41,495] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20210406_c184b117e662d27b3ded/null_1.2.826.0.1.3680043.8.498.85567042511196906763826001786479037113/US1.2.826.0.1.3680043.8.498.68167702618329745157966416745104746075.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:15:41,495] [WARNING] (pydicom) - The value length (20) exceeds the maximum length of 16 allowed for VR SH.
# The value length (20) exceeds the maximum length of 16 allowed for VR SH.
# [2026-04-28 15:15:41,496] [INFO] (root) - Finding series for Selection named: highb
# [2026-04-28 15:15:41,497] [INFO] (root) - Searching study, : 1.2.826.0.1.3680043.8.498.97185111240360891764053791138326704688
#   # of series: 1
# [2026-04-28 15:15:41,497] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.85567042511196906763826001786479037113
# [2026-04-28 15:15:41,497] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:15:41,497] [INFO] (root) -     Series attribute Modality value: US
# [2026-04-28 15:15:41,497] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:15:41,497] [INFO] (root) - This series does not match the selection conditions.
# [2026-04-28 15:15:41,497] [INFO] (root) - Finding series for Selection named: adc
# [2026-04-28 15:15:41,497] [INFO] (root) - Searching study, : 1.2.826.0.1.3680043.8.498.97185111240360891764053791138326704688
#   # of series: 1
# [2026-04-28 15:15:41,497] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.85567042511196906763826001786479037113
# [2026-04-28 15:15:41,497] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:15:41,497] [INFO] (root) -     Series attribute Modality value: US
# [2026-04-28 15:15:41,497] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:15:41,498] [INFO] (root) - This series does not match the selection conditions.
# [2026-04-28 15:15:41,498] [INFO] (root) - Finding series for Selection named: t2
# [2026-04-28 15:15:41,498] [INFO] (root) - Searching study, : 1.2.826.0.1.3680043.8.498.97185111240360891764053791138326704688
#   # of series: 1
# [2026-04-28 15:15:41,498] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.85567042511196906763826001786479037113
# [2026-04-28 15:15:41,498] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:15:41,498] [INFO] (root) -     Series attribute Modality value: US
# [2026-04-28 15:15:41,498] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:15:41,498] [INFO] (root) - This series does not match the selection conditions.
# Exception occurred for operator: 'series_to_vol_HIGHB'
# Traceback (most recent call last):
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 60, in compute
#     image = self.convert_to_image(study_selected_series_list)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 67, in convert_to_image
#     raise ValueError("Missing expected input 'study_selected_series_list'")
# ValueError: Missing expected input 'study_selected_series_list'
# Exception occurred for operator: 'series_to_vol_ADC'
# Traceback (most recent call last):
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 60, in compute
#     image = self.convert_to_image(study_selected_series_list)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 67, in convert_to_image
#     raise ValueError("Missing expected input 'study_selected_series_list'")
# ValueError: Missing expected input 'study_selected_series_list'
# Exception occurred for operator: 'series_to_vol_T2'
# Traceback (most recent call last):
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 60, in compute
#     image = self.convert_to_image(study_selected_series_list)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 67, in convert_to_image
#     raise ValueError("Missing expected input 'study_selected_series_list'")
# ValueError: Missing expected input 'study_selected_series_list'
# [info] [greedy_scheduler.cpp:369] Scheduler stopped: Some entities are waiting for execution, but there are no periodic or async entities to get out of the deadlock.
# [info] [greedy_scheduler.cpp:398] Scheduler finished.
# [info] [gxf_executor.cpp:1783] Graph execution deactivating. Fragment:
# [info] [gxf_executor.cpp:1784] Deactivating Graph...
# [info] [gxf_executor.cpp:1787] Graph execution finished. Fragment:
# [info] [gxf_executor.cpp:229] Destroying context
#   DONE (exit 0)
#   Status: FAIL_EMPTY_OUTPUT  [missing: t2,adc,highb]
#   Reason: No output files produced at all - most likely every series selector rejected the input (check SeriesDescription regexes in prostate_mri_lesion_seg_app/app.py).
#   Cooldown 10s before next case...
# ========================================
# [3/40] Patient: 20211223_83e281a364289a3e3c1e
#   Input:  test-data//20211223_83e281a364289a3e3c1e/
#   Output: output_charlie//20211223_83e281a364289a3e3c1e
#   Running on GPU...
# [2026-04-28 15:16:01,919] [INFO] (root) - Parsed args: Namespace(log_level=None, input=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20211223_83e281a364289a3e3c1e'), output=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20211223_83e281a364289a3e3c1e'), model=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/models'), workdir=None, argv=['/home/anson/work/research-contributions/prostate-mri-lesion-seg/scripts/../prostate_mri_lesion_seg_app', '-i', 'test-data//20211223_83e281a364289a3e3c1e/', '-o', 'output_charlie//20211223_83e281a364289a3e3c1e', '-m', 'models/'])
# [2026-04-28 15:16:01,924] [INFO] (root) - AppContext object: AppContext(input_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20211223_83e281a364289a3e3c1e, output_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20211223_83e281a364289a3e3c1e, model_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/models, workdir=)
# [2026-04-28 15:16:01,925] [INFO] (app.AIProstateLesionSegApp) - App input and output path: /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20211223_83e281a364289a3e3c1e, /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20211223_83e281a364289a3e3c1e
# [info] [gxf_executor.cpp:210] Creating context
# [warning] [gxf_extension_manager.cpp:132] Unable to load extension from 'libgxf_bayer_demosaic.so' (error: libnppicc.so.11: cannot open shared object file: No such file or directory)
# [info] [gxf_executor.cpp:1595] Loading extensions from configs...
# [info] [gxf_executor.cpp:1741] Activating Graph...
# [info] [gxf_executor.cpp:1771] Running Graph...
# [info] [gxf_executor.cpp:1773] Waiting for completion...
# [info] [gxf_executor.cpp:1774] Graph execution waiting. Fragment:
# [info] [greedy_scheduler.cpp:190] Scheduling 15 entities
# [2026-04-28 15:16:01,982] [INFO] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - No or invalid input path from the optional input port: None
# [2026-04-28 15:16:02,003] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20211223_83e281a364289a3e3c1e/L MLO_1.2.826.0.1.3680043.8.498.32837961922191986277338173505004522186/MG1.2.826.0.1.3680043.8.498.63295460029883118595788879760470046707.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:02,003] [WARNING] (pydicom) - The value length (20) exceeds the maximum length of 16 allowed for VR SH.
# The value length (20) exceeds the maximum length of 16 allowed for VR SH.
# [2026-04-28 15:16:02,004] [INFO] (root) - Finding series for Selection named: highb
# [2026-04-28 15:16:02,004] [INFO] (root) - Searching study, : 1.2.826.0.1.3680043.8.498.11301493686912991986130665391062405607
#   # of series: 1
# [2026-04-28 15:16:02,004] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.32837961922191986277338173505004522186
# [2026-04-28 15:16:02,005] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:16:02,005] [INFO] (root) -     Series attribute Modality value: MG
# [2026-04-28 15:16:02,005] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:16:02,005] [INFO] (root) - This series does not match the selection conditions.
# [2026-04-28 15:16:02,005] [INFO] (root) - Finding series for Selection named: adc
# [2026-04-28 15:16:02,005] [INFO] (root) - Searching study, : 1.2.826.0.1.3680043.8.498.11301493686912991986130665391062405607
#   # of series: 1
# [2026-04-28 15:16:02,005] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.32837961922191986277338173505004522186
# [2026-04-28 15:16:02,005] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:16:02,005] [INFO] (root) -     Series attribute Modality value: MG
# [2026-04-28 15:16:02,005] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:16:02,005] [INFO] (root) - This series does not match the selection conditions.
# [2026-04-28 15:16:02,006] [INFO] (root) - Finding series for Selection named: t2
# [2026-04-28 15:16:02,006] [INFO] (root) - Searching study, : 1.2.826.0.1.3680043.8.498.11301493686912991986130665391062405607
#   # of series: 1
# [2026-04-28 15:16:02,006] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.32837961922191986277338173505004522186
# [2026-04-28 15:16:02,006] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:16:02,006] [INFO] (root) -     Series attribute Modality value: MG
# [2026-04-28 15:16:02,006] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:16:02,006] [INFO] (root) - This series does not match the selection conditions.
# Exception occurred for operator: 'series_to_vol_HIGHB'
# Traceback (most recent call last):
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 60, in compute
#     image = self.convert_to_image(study_selected_series_list)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 67, in convert_to_image
#     raise ValueError("Missing expected input 'study_selected_series_list'")
# ValueError: Missing expected input 'study_selected_series_list'
# Exception occurred for operator: 'series_to_vol_ADC'
# Traceback (most recent call last):
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 60, in compute
#     image = self.convert_to_image(study_selected_series_list)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 67, in convert_to_image
#     raise ValueError("Missing expected input 'study_selected_series_list'")
# ValueError: Missing expected input 'study_selected_series_list'
# Exception occurred for operator: 'series_to_vol_T2'
# Traceback (most recent call last):
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 60, in compute
#     image = self.convert_to_image(study_selected_series_list)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/deploy/operators/dicom_series_to_volume_operator.py", line 67, in convert_to_image
#     raise ValueError("Missing expected input 'study_selected_series_list'")
# ValueError: Missing expected input 'study_selected_series_list'
# [info] [greedy_scheduler.cpp:369] Scheduler stopped: Some entities are waiting for execution, but there are no periodic or async entities to get out of the deadlock.
# [info] [greedy_scheduler.cpp:398] Scheduler finished.
# [info] [gxf_executor.cpp:1783] Graph execution deactivating. Fragment:
# [info] [gxf_executor.cpp:1784] Deactivating Graph...
# [info] [gxf_executor.cpp:1787] Graph execution finished. Fragment:
# [info] [gxf_executor.cpp:229] Destroying context
#   DONE (exit 0)
#   Status: FAIL_EMPTY_OUTPUT  [missing: t2,adc,highb]
#   Reason: No output files produced at all - most likely every series selector rejected the input (check SeriesDescription regexes in prostate_mri_lesion_seg_app/app.py).
#   Cooldown 10s before next case...
# ========================================
# [4/40] Patient: 20230221_272da2e6002c60fb7921
#   Input:  test-data//20230221_272da2e6002c60fb7921/
#   Output: output_charlie//20230221_272da2e6002c60fb7921
#   SKIPPING (resume mode, 194 output files already exist)
#   Audit: row for '20230221_272da2e6002c60fb7921' already logged; not re-appending.
# ========================================
# [5/40] Patient: 20230221_823319ef014cb44958c1
#   Input:  test-data//20230221_823319ef014cb44958c1/
#   Output: output_charlie//20230221_823319ef014cb44958c1
#   Running on GPU...
# [2026-04-28 15:16:22,681] [INFO] (root) - Parsed args: Namespace(log_level=None, input=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1'), output=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20230221_823319ef014cb44958c1'), model=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/models'), workdir=None, argv=['/home/anson/work/research-contributions/prostate-mri-lesion-seg/scripts/../prostate_mri_lesion_seg_app', '-i', 'test-data//20230221_823319ef014cb44958c1/', '-o', 'output_charlie//20230221_823319ef014cb44958c1', '-m', 'models/'])
# [2026-04-28 15:16:22,691] [INFO] (root) - AppContext object: AppContext(input_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1, output_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20230221_823319ef014cb44958c1, model_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/models, workdir=)
# [2026-04-28 15:16:22,691] [INFO] (app.AIProstateLesionSegApp) - App input and output path: /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1, /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/20230221_823319ef014cb44958c1
# [info] [gxf_executor.cpp:210] Creating context
# [warning] [gxf_extension_manager.cpp:132] Unable to load extension from 'libgxf_bayer_demosaic.so' (error: libnppicc.so.11: cannot open shared object file: No such file or directory)
# [info] [gxf_executor.cpp:1595] Loading extensions from configs...
# [info] [gxf_executor.cpp:1741] Activating Graph...
# [info] [gxf_executor.cpp:1771] Running Graph...
# [info] [gxf_executor.cpp:1773] Waiting for completion...
# [info] [gxf_executor.cpp:1774] Graph execution waiting. Fragment:
# [info] [greedy_scheduler.cpp:190] Scheduling 15 entities
# [2026-04-28 15:16:22,757] [INFO] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - No or invalid input path from the optional input port: None
# [2026-04-28 15:16:22,768] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.12864204674152882656382648384988168803.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,768] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.13265814185587020108786020894376997963.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,769] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.25557645226831170529233691310937757183.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,769] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.69636207721366568451196983743690702959.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,772] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.62786833571740492596208367028220984937.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,775] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.75805011950133554166312404218343617338.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,775] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.67541806526731992411270811844054695281.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,776] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.62147981269154071349515447410662977042.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,776] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.23833442125882352715599697783863391001.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,787] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.70431514951376877737373575859286091971.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,787] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.78079636074425946349661810586073508420.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,788] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.74050533977901027503680637921848233293.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,788] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.11366182721004302584364143450881179805.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,791] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.12295939878657878169216900433364825550.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,791] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.11238547424802912199082336692119085963.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,797] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.11170717442556471462616371329772541308.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,807] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.45086222697262964367379357169103725916.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,810] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.29277721683062284060443803404109210390.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,813] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.10804236890342374064597359237403493627.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,814] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.35711031930961759285923600384476209700.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,814] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.10888115295877695629143514836422155907.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,820] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.28379630297123573104803794256653487600.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,825] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.11454570347015463111204036375140673483.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,828] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.13149483827016122275086352304737395288.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,828] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.88504015302897033858055889648386701072.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,833] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.38704928529437634984207380811931074382.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,839] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.96867978084446547136814702417650183273.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,840] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.36942156141484041304728600249020797213.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,842] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/AX_t1_tse_1.2.826.0.1.3680043.8.498.13235048937608250683195459278666896700/MR1.2.826.0.1.3680043.8.498.57818234708056233011607524542365138234.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,842] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/SAG_t2_tse_1.2.826.0.1.3680043.8.498.61314708716880866771539362228036270035/MR1.2.826.0.1.3680043.8.498.36251563708279037648097292028554224212.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,842] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/SAG_t2_tse_1.2.826.0.1.3680043.8.498.61314708716880866771539362228036270035/MR1.2.826.0.1.3680043.8.498.18553996693743153619298866740091382983.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,843] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/SAG_t2_tse_1.2.826.0.1.3680043.8.498.61314708716880866771539362228036270035/MR1.2.826.0.1.3680043.8.498.57899294218270475793079291420198447553.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,844] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/SAG_t2_tse_1.2.826.0.1.3680043.8.498.61314708716880866771539362228036270035/MR1.2.826.0.1.3680043.8.498.10229489852583195177336187277424538503.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,844] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/SAG_t2_tse_1.2.826.0.1.3680043.8.498.61314708716880866771539362228036270035/MR1.2.826.0.1.3680043.8.498.12579827197474096451045049210477461521.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,845] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/SAG_t2_tse_1.2.826.0.1.3680043.8.498.61314708716880866771539362228036270035/MR1.2.826.0.1.3680043.8.498.52702166822235318410980598200573143637.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,845] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/SAG_t2_tse_1.2.826.0.1.3680043.8.498.61314708716880866771539362228036270035/MR1.2.826.0.1.3680043.8.498.26750625635609589710562422244047517245.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,846] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/SAG_t2_tse_1.2.826.0.1.3680043.8.498.61314708716880866771539362228036270035/MR1.2.826.0.1.3680043.8.498.67231397193347988799653311273008585688.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2026-04-28 15:16:22,848] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/20230221_823319ef014cb44958c1/SAG_t2_tse_1.2.826.0.1.3680043.8.498.61314708716880866771539362228036270035/MR1.2.826.0.1.3680043.8.498.79653312393090065576508627129048008762.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# ...
# [2026-04-28 15:29:13,730] [INFO] (root) -     Series attribute SeriesDescription value: dwi_zoom_b1800
# [2026-04-28 15:29:13,730] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:29:13,730] [INFO] (root) - This series does not match the selection conditions.
# [2026-04-28 15:29:13,730] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.15823155683746696903938112838402507710
# [2026-04-28 15:29:13,730] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:29:13,730] [INFO] (root) -     Series attribute Modality value: MR
# [2026-04-28 15:29:13,730] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '^(?!.*(?:localizer|survey))(?=.*adc).*'
# [2026-04-28 15:29:13,730] [INFO] (root) -     Series attribute SeriesDescription value: eet2_tse_tra_obl
# [2026-04-28 15:29:13,730] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:29:13,730] [INFO] (root) - This series does not match the selection conditions.
# [2026-04-28 15:29:13,730] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.56931969711401508826573169583750372581
# [2026-04-28 15:29:13,730] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:29:13,730] [INFO] (root) -     Series attribute Modality value: MR
# [2026-04-28 15:29:13,730] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '^(?!.*(?:localizer|survey))(?=.*adc).*'
# [2026-04-28 15:29:13,730] [INFO] (root) -     Series attribute SeriesDescription value: dReg - dwi_zoom_b0_500_1000_ADC
# [2026-04-28 15:29:13,731] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:29:13,731] [INFO] (root) - Selected Series, UID: 1.2.826.0.1.3680043.8.498.56931969711401508826573169583750372581
# [2026-04-28 15:29:13,731] [INFO] (root) - Finding series for Selection named: t2
# [2026-04-28 15:29:13,731] [INFO] (root) - Searching study, : 1.2.826.0.1.3680043.8.498.83977146023570936512746069577178426219
#   # of series: 13
# [2026-04-28 15:29:13,731] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.45157401500864190856038033735635420935
# [2026-04-28 15:29:13,731] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:29:13,731] [INFO] (root) -     Series attribute Modality value: MR
# [2026-04-28 15:29:13,731] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '^(?!.*(?:obl|oblq|oblique|obq|cor|sag|pelvis|whole[_ ]?pelvis|wholepelvis|tirm|stir|space|localizer|survey|t1|\\+c|adc|dwi|diff|tracew?|_fs_|_fs\\b|\\bfs_|\\bfs\\b))(?=.*t2)(?=.*(?:tra|\\bax\\b|axial|^ax[_ ]|_ax[_ ]|AX[_ ])).*'
# [2026-04-28 15:29:13,731] [INFO] (root) -     Series attribute SeriesDescription value: e-THRIVE_tra_fs+c_wholepelvis
# [2026-04-28 15:29:13,731] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:29:13,732] [INFO] (root) - This series does not match the selection conditions.
# [2026-04-28 15:29:13,732] [INFO] (root) - Working on series, instance UID: 1.2.826.0.1.3680043.8.498.23057831459567339863154848116047228450
# [2026-04-28 15:29:13,732] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2026-04-28 15:29:13,732] [INFO] (root) -     Series attribute Modality value: MR
# [2026-04-28 15:29:13,732] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '^(?!.*(?:obl|oblq|oblique|obq|cor|sag|pelvis|whole[_ ]?pelvis|wholepelvis|tirm|stir|space|localizer|survey|t1|\\+c|adc|dwi|diff|tracew?|_fs_|_fs\\b|\\bfs_|\\bfs\\b))(?=.*t2)(?=.*(?:tra|\\bax\\b|axial|^ax[_ ]|_ax[_ ]|AX[_ ])).*'
# [2026-04-28 15:29:13,732] [INFO] (root) -     Series attribute SeriesDescription value: et2_tse_tra
# [2026-04-28 15:29:13,732] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2026-04-28 15:29:13,732] [INFO] (root) - Selected Series, UID: 1.2.826.0.1.3680043.8.498.23057831459567339863154848116047228450
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Converted Image object metadata:
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesInstanceUID: 1.2.826.0.1.3680043.8.498.23057831459567339863154848116047228450, type <class 'str'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesDate: 20230816, type <class 'str'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesTime: 112335, type <class 'str'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Modality: MR, type <class 'str'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesDescription: et2_tse_tra, type <class 'str'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - PatientPosition: HFS, type <class 'str'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesNumber: 802, type <class 'int'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - row_pixel_spacing: 0.56818181276321, type <class 'float'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - col_pixel_spacing: 0.56818181276321, type <class 'float'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - depth_pixel_spacing: 1.0, type <class 'float'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - row_direction_cosine: [1.0, 0.0, 0.0], type <class 'list'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - col_direction_cosine: [0.0, 1.0, 0.0], type <class 'list'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyInstanceUID: 1.2.826.0.1.3680043.8.498.83977146023570936512746069577178426219, type <class 'str'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyDate: 20230816, type <class 'str'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyTime: 104959, type <class 'str'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyDescription: MRI Prostate (Multi-Parametric), type <class 'str'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - AccessionNumber: eed80f7e38dd92b9cb9d, type <class 'str'>
# [2026-04-28 15:29:13,742] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - selection_name: t2, type <class 'str'>
# Beginning organ segmentation...
# [2026-04-28 15:29:13,990] [INFO] (Loaded image) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([352, 352, 1])
# Value range: (0.0, 369.0)
# [2026-04-28 15:29:13,990] [INFO] (Channel-first image) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([1, 352, 352, 1])
# Value range: (0.0, 369.0)
# [2026-04-28 15:29:14,004] [INFO] (Resampled and normalized image) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([1, 352, 352, 1])
# Value range: (-1.1191517114639282, 3.907902717590332)
# [2026-04-28 15:29:14,838] [INFO] (Model output) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([2, 352, 352, 1])
# Value range: (3.660175570985302e-05, 0.9999634027481079)
# [2026-04-28 15:29:14,846] [INFO] (Inverted output) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([2, 352, 352, 1])
# Value range: (3.660175570985302e-05, 0.9999634027481079)
# [2026-04-28 15:29:14,859] [INFO] (AsDiscrete output) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([1, 352, 352, 1])
# Value range: (0.0, 0.0)
# [2026-04-28 15:29:14,859] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Output Seg image numpy array shaped: (1, 352, 352)
# [2026-04-28 15:29:14,859] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Output Seg image pixel max value: 0
# [2026-04-28 15:29:14,860] [WARNING] (custom_lesion_seg_operator.ProstateLesionSegOperator) - T2: No affine transform found in metadata. Using identity matrix. This series likely has only 1 slice — results will be unreliable.
# [2026-04-28 15:29:14,860] [WARNING] (custom_lesion_seg_operator.ProstateLesionSegOperator) - Organ: No affine transform found in metadata. Using identity matrix. This series likely has only 1 slice — results will be unreliable.
# 2026-04-28 15:29:14,878 INFO image_writer.py:197 - writing: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/sgh_data_patient_4/t2/t2.nii.gz
# 2026-04-28 15:29:14,899 INFO image_writer.py:197 - writing: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/sgh_data_patient_4/adc/adc.nii.gz
# 2026-04-28 15:29:14,910 INFO image_writer.py:197 - writing: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/sgh_data_patient_4/highb/highb.nii.gz
# 2026-04-28 15:29:14,919 INFO image_writer.py:197 - writing: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/sgh_data_patient_4/organ/organ.nii.gz
# [2026-04-28 15:29:14,926] [WARNING] (custom_lesion_seg_operator.ProstateLesionSegOperator) - Skipping lesion inference: organ mask is empty (max=0.0). Returning empty lesion mask.
# [2026-04-28 15:29:14,931] [INFO] (root) - T2 DICOM series matched by UID: /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/sgh_data_patient_4/et2_tse_tra_1.2.826.0.1.3680043.8.498.23057831459567339863154848116047228450
# [2026-04-28 15:29:14,935] [WARNING] (pydicom) - The value length (20) exceeds the maximum length of 16 allowed for VR SH.
# [2026-04-28 15:29:14,939] [INFO] (root) - Patched StudyID (from AccessionNumber) on 1/1 DICOM files in temp dir: /tmp/rtstruct_patched_ci3xaj5j
# [2026-04-28 15:29:14,943] [WARNING] (pydicom) - 'FileDataset.is_little_endian' will be removed in v4.0, set the Transfer Syntax UID or use the 'little_endian' argument with FileDataset.save_as() or dcmwrite() instead
# [2026-04-28 15:29:14,943] [WARNING] (pydicom) - 'FileDataset.is_implicit_VR' will be removed in v4.0, set the Transfer Syntax UID or use the 'implicit_vr' argument with FileDataset.save_as() or dcmwrite() instead
# [2026-04-28 15:29:14,950] [INFO] (root) - Organ RTSTRUCT created (binary): /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/sgh_data_patient_4/organ/organ_RTSTRUCT.dcm
# Writing file to /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/sgh_data_patient_4/organ/organ_RTSTRUCT.dcm
# [2026-04-28 15:29:14,955] [WARNING] (pydicom) - The value length (20) exceeds the maximum length of 16 allowed for VR SH.
# [2026-04-28 15:29:14,957] [INFO] (root) - Patched StudyID (from AccessionNumber) on 1/1 DICOM files in temp dir: /tmp/rtstruct_patched_r0o7ykxc
# [2026-04-28 15:29:14,959] [WARNING] (pydicom) - 'FileDataset.is_little_endian' will be removed in v4.0, set the Transfer Syntax UID or use the 'little_endian' argument with FileDataset.save_as() or dcmwrite() instead
# [2026-04-28 15:29:14,959] [WARNING] (pydicom) - 'FileDataset.is_implicit_VR' will be removed in v4.0, set the Transfer Syntax UID or use the 'implicit_vr' argument with FileDataset.save_as() or dcmwrite() instead
# [INFO]: ROI mask is empty
# Writing file to /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/sgh_data_patient_4/lesion/lesion_RTSTRUCT.dcm
# [2026-04-28 15:29:14,969] [INFO] (root) - RTSTRUCT saved to: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/sgh_data_patient_4/lesion/lesion_RTSTRUCT.dcm
# [2026-04-28 15:29:14,969] [INFO] (root) - Lesion RTSTRUCT created: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/sgh_data_patient_4/lesion/lesion_RTSTRUCT.dcm
# [2026-04-28 15:29:14,971] [WARNING] (pydicom) - The value length (20) exceeds the maximum length of 16 allowed for VR SH.
# [2026-04-28 15:29:14,974] [INFO] (root) - Patched StudyID (from AccessionNumber) on 1/1 DICOM files in temp dir: /tmp/rtstruct_patched_i07dxo5m
# [2026-04-28 15:29:14,976] [WARNING] (pydicom) - 'FileDataset.is_little_endian' will be removed in v4.0, set the Transfer Syntax UID or use the 'little_endian' argument with FileDataset.save_as() or dcmwrite() instead
# [2026-04-28 15:29:14,976] [WARNING] (pydicom) - 'FileDataset.is_implicit_VR' will be removed in v4.0, set the Transfer Syntax UID or use the 'implicit_vr' argument with FileDataset.save_as() or dcmwrite() instead
# Writing file to /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/sgh_data_patient_4/combined_organ_lesion_RTSTRUCT.dcm
# [2026-04-28 15:29:14,996] [INFO] (root) - Combined organ+lesion RTSTRUCT created: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output_charlie/sgh_data_patient_4/combined_organ_lesion_RTSTRUCT.dcm
# [2026-04-28 15:29:15,001] [INFO] (custom_lesion_seg_operator.ProstateLesionSegOperator) - DICOM copy: t2 — 1 files from et2_tse_tra_1.2.826.0.1.3680043.8.498.23057831459567339863154848116047228450
# [2026-04-28 15:29:15,006] [INFO] (custom_lesion_seg_operator.ProstateLesionSegOperator) - DICOM copy: adc — 5 files from dReg - dwi_zoom_b0_500_1000_ADC_1.2.826.0.1.3680043.8.498.56931969711401508826573169583750372581
# [2026-04-28 15:29:15,010] [INFO] (custom_lesion_seg_operator.ProstateLesionSegOperator) - DICOM copy: highb — 3 files from dwi_zoom_b1800_1.2.826.0.1.3680043.8.498.59682719095324234281419902423506808620
# Beginning lesion classification...
# Loading images...
# [2026-04-28 15:29:15,131] [WARNING] (root) - Classifier: No affine transform found. Using identity matrix.
# Resampling ADC/HIGHB to match T2...
# Resampling all channels to (0.5, 0.5, 0.5)...
# Combined volume shape: torch.Size([4, 703, 703, 1])
# Inputs shape:  (703, 703, 1)
# nda_resize_crops shape:  torch.Size([3, 703, 703, 1])
# {'Organ': 'Prostate', 'Major_Axis_Length': 203.22647465327935, 'Volume': 0.0}
# [info] [greedy_scheduler.cpp:369] Scheduler stopped: Some entities are waiting for execution, but there are no periodic or async entities to get out of the deadlock.
# [info] [greedy_scheduler.cpp:398] Scheduler finished.
# [info] [gxf_executor.cpp:1783] Graph execution deactivating. Fragment:
# [info] [gxf_executor.cpp:1784] Deactivating Graph...
# [info] [gxf_executor.cpp:1787] Graph execution finished. Fragment:
# [info] [gxf_executor.cpp:229] Destroying context
#   DONE (exit 0)
#   Status: SUCCESS_EMPTY_LESION
#   Reason: Organ mask was empty (no prostate detected); lesion inference was intentionally skipped and an empty lesion mask was written (see custom_lesion_seg_operator.py).
#
# ========================================
# Batch processing complete.
#   Total: 40  Succeeded: 27  Failed: 0  Skipped: 13
#   Exit-code counters above reflect the app's raw return status.
#   For the full per-case outcome (including silent empty outputs)
#   inspect the audit CSV: output_charlie//batch_audit_log.csv
#
# ----- Per-status breakdown from audit CSV -----
# Audit CSV: output_charlie/batch_audit_log.csv
# Total rows: 49
#   FAIL_EMPTY_OUTPUT           23
#   SUCCESS_COMPLETE            25
#   SUCCESS_EMPTY_LESION         1

# %%
import os
from collections import defaultdict
from pathlib import Path
import pydicom

FIELDS = [
    "Modality",
    "SeriesDescription",
    "SeriesInstanceUID",
    "StudyInstanceUID",
    "ImageType",
    "ProtocolName",
    "SequenceName",
    "SequenceVariant",
    "ScanningSequence",
    "BodyPartExamined",
    "Manufacturer",
    "ManufacturerModelName",
    "MagneticFieldStrength",
]

def read_header(path: Path):
    try:
        ds = pydicom.dcmread(
            str(path),
            stop_before_pixels=True,
            force=True,
            specific_tags=FIELDS,
        )
        return ds
    except Exception:
        return None

def normalize_value(val):
    if val is None:
        return None
    if isinstance(val, (list, tuple)):
        return [str(v) for v in val]
    return str(val)

def scan_dir(root: Path):
    series_map = defaultdict(list)
    total_files = 0
    dicom_files = 0

    for dirpath, _, filenames in os.walk(root):
        for fname in filenames:
            total_files += 1
            if fname.endswith(":Zone.Identifier"):
                continue
            path = Path(dirpath) / fname
            ds = read_header(path)
            if ds is None:
                continue
            dicom_files += 1
            sid = getattr(ds, "SeriesInstanceUID", "UNKNOWN_SERIES")
            series_map[sid].append(ds)

    return total_files, dicom_files, series_map

def summarize_series(series_map):
    summaries = []
    for sid, dsets in series_map.items():
        ds = dsets[0]
        summary = {f: normalize_value(getattr(ds, f, None)) for f in FIELDS}
        summary["NumInstances"] = len(dsets)
        summaries.append(summary)
    summaries.sort(key=lambda x: (x.get("SeriesDescription") or "", -x["NumInstances"]))
    return summaries

def print_summary(title, total_files, dicom_files, summaries):
    print(f"\n=== {title} ===")
    print(f"Files scanned: {total_files}, DICOM files read: {dicom_files}")
    if not summaries:
        print("No DICOM series found.")
        return
    for s in summaries:
        print("-" * 80)
        print(f"SeriesInstanceUID: {s.get('SeriesInstanceUID')}")
        print(f"SeriesDescription: {s.get('SeriesDescription')}")
        print(f"ImageType: {s.get('ImageType')}")
        print(f"Modality: {s.get('Modality')}")
        print(f"ProtocolName: {s.get('ProtocolName')}")
        print(f"SequenceName: {s.get('SequenceName')}")
        print(f"SequenceVariant: {s.get('SequenceVariant')}")
        print(f"ScanningSequence: {s.get('ScanningSequence')}")
        print(f"BodyPartExamined: {s.get('BodyPartExamined')}")
        print(f"Manufacturer: {s.get('Manufacturer')}")
        print(f"Model: {s.get('ManufacturerModelName')}")
        print(f"B0 (T): {s.get('MagneticFieldStrength')}")
        print(f"StudyInstanceUID: {s.get('StudyInstanceUID')}")
        print(f"NumInstances: {s.get('NumInstances')}")

# Set directories to scan
paths = [
    "/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000",
    # "/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/sgh_data_patient_2",
]

for p in paths:
    root = Path(p).expanduser().resolve()
    total_files, dicom_files, series_map = scan_dir(root)
    summaries = summarize_series(series_map)
    print_summary(str(root), total_files, dicom_files, summaries)

print("\nIf you see 'No DICOM series found', run this on the original DICOM inputs under test-data.")
# Out:
# === /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000 ===
# Files scanned: 884, DICOM files read: 884
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.193930593885836732899229869284
# SeriesDescription: ep2d_diff_tra_DYNDIST
# ImageType: ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW', 'DIS2D']
# Modality: MR
# ProtocolName: ep2d_diff_tra
# SequenceName: *ep_b50t
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: EP
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 57
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.338465037878158762935951983202
# SeriesDescription: ep2d_diff_tra_DYNDISTCALC_BVAL
# ImageType: ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW', 'DIS2D']
# Modality: MR
# ProtocolName: ep2d_diff_tra
# SequenceName: *ep_b50_800
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: EP
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 19
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.339319789559896104041345048780
# SeriesDescription: ep2d_diff_tra_DYNDIST_ADC
# ImageType: ['DERIVED', 'PRIMARY', 'DIFFUSION', 'ADC', 'DIS2D']
# Modality: MR
# ProtocolName: ep2d_diff_tra
# SequenceName: *ep_b50_800
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: EP
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 19
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.604184452348902957788528403471
# SeriesDescription: t2_tse_cor
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# Modality: MR
# ProtocolName: t2_tse_cor
# SequenceName: *tse2d1_25
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: SE
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 15
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.250911858840767891342974687368
# SeriesDescription: t2_tse_sag
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# Modality: MR
# ProtocolName: t2_tse_sag
# SequenceName: *tse2d1_25
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: SE
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 19
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.160028252338004527274326500702
# SeriesDescription: t2_tse_tra
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
# Modality: MR
# ProtocolName: t2_tse_tra
# SequenceName: *tse2d1_25
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: SE
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 19
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.625704662293970847122565067276
# SeriesDescription: tfl_3d PD ref_tra_1.5x1.5_t3
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_3d PD ref_tra_1.5x1.5_t3
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.967820609209271194987242085821
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.317929700804780815731620434844
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.266505959712404083237782464782
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.187763029630310579229528009542
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.189535767553259401630065221021
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.126632998669444555412261856220
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.184788576496632993157916303299
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.259322736784885512680445117827
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.151728887369260520314224718051
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.277459280855195938688152606372
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.273765291302119699966350214900
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.150007712891145271532985158929
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.306696495147116782694292357984
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.208459924840728476727676915977
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.265448235744872797474034603703
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.180109902642189808280888403852
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.209410511567680378445846204605
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.248663600711869904549249794359
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.195838071224205243051581616891
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.146597193262543166007010570217
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.298504794464342637266426766689
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.166175691859458891194031186687
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.168471407488465651121507943787
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.306364380682382298190563894176
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.355585112247832093231405602962
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.246474430227060314590110801678
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.259303517736468941739449805555
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.228444563198065384912857177868
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.112581604671944984617727867203
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.176298575525738829487073716278
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.371650507821072515918119824954
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.284642576349469736179769126743
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.100000082759836574166944843130
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.228746836592786437859224132096
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.275753954418694472773319642829
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.615097943137744988742545086304
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.173817844115733703701582076441
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.278225736780816868200005769147
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.159334873184281958213720499215
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.110623467519168957976143850858
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.253767375938329168709160185727
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.334533383512723497675286993488
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.258928921259547436477290574269
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.221548728112603643967364193717
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
# --------------------------------------------------------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.252250955024999370855171017316
# SeriesDescription: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# ImageType: ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
# Modality: MR
# ProtocolName: tfl_dyn_fast_tra_1.5x1.5_t3.5sec
# SequenceName: *tfl3d1_16
# SequenceVariant: ['SK', 'SP', 'OSP']
# ScanningSequence: GR
# BodyPartExamined: PROSTATE
# Manufacturer: SIEMENS
# Model: Skyra
# B0 (T): 3
# StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.158323547117540061132729905711
# NumInstances: 16
#
# If you see 'No DICOM series found', run this on the original DICOM inputs under test-data.

# %% [markdown]
# Build the `lesion_seg_workflow_app` container, i.e., the MONAI Application Package (MAP). This may take more than 15 minutes during the initial build.

# %%
# Package code into MAP
APP_DIR="prostate_mri_lesion_seg_app"
MODEL_DIR=APP_DIR + "/models"
# !monai-deploy package $APP_DIR -l DEBUG -t lesion_seg_workflow_app -m $MODEL_DIR -c $APP_DIR/app.yaml --platform x64-workstation

# %%
# %%bash
#
# monai-deploy run lesion_seg_workflow_app-x64-workstation-dgpu-linux-amd64:1.0 -i test-data/ProstateX-0004/ -o output/
# Out:
# [2025-03-10 15:30:48,718] [INFO] (runner) - Checking dependencies...
# [2025-03-10 15:30:48,718] [INFO] (runner) - --> Verifying if "docker" is installed...
#
# [2025-03-10 15:30:48,718] [INFO] (runner) - --> Verifying if "docker-buildx" is installed...
#
# [2025-03-10 15:30:48,718] [INFO] (runner) - --> Verifying if "lesion_seg_workflow_app-x64-workstation-dgpu-linux-amd64:1.0" is available...
#
# [2025-03-10 15:30:48,745] [INFO] (runner) - Reading HAP/MAP manifest...
# e78bc1d0b1626d397f0a117855e31d21940746a6ed6179747baaaab9b200281f
# [2025-03-10 15:30:51,406] [INFO] (runner) - --> Verifying if "nvidia-ctk" is installed...
#
# [2025-03-10 15:30:51,406] [INFO] (runner) - --> Verifying "nvidia-ctk" version...
#
# [2025-03-10 15:30:53,579] [INFO] (common) - Launching container (3baab5796e76) using image 'lesion_seg_workflow_app-x64-workstation-dgpu-linux-amd64:1.0'...
#     container name:      nervous_dijkstra
#     host name:           8038Kidwell
#     network:             host
#     user:                1000:1000
#     ulimits:             memlock=-1:-1, stack=67108864:67108864
#     cap_add:             CAP_SYS_PTRACE
#     ipc mode:            host
#     shared memory size:  67108864
#     devices:
#     group_add:           44
# 2025-03-10 19:30:54 [INFO] Launching application python3 /opt/holoscan/app ...
#
# [info] [fragment.cpp:599] Loading extensions from configs...
#
# [info] [gxf_executor.cpp:264] Creating context
#
# [2025-03-10 19:30:56,858] [INFO] (root) - Parsed args: Namespace(log_level=None, input=None, output=None, model=None, workdir=None, argv=['/opt/holoscan/app'])
#
# [2025-03-10 19:30:56,860] [INFO] (root) - AppContext object: AppContext(input_path=/var/holoscan/input, output_path=/var/holoscan/output, model_path=/opt/holoscan/models, workdir=/var/holoscan)
#
# [2025-03-10 19:30:56,860] [INFO] (app.AIProstateLesionSegApp) - App input and output path: /var/holoscan/input, /var/holoscan/output
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'input_folder'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'dicom_study_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'dicom_study_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'dicom_study_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'study_selected_series_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'study_selected_series_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'study_selected_series_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_highb'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_organ_seg'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_adc'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_t2'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_lesion_seg'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_highb'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_organ_seg'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_adc'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_t2'
#
# [info] [gxf_executor.cpp:2208] Activating Graph...
#
# [info] [gxf_executor.cpp:2238] Running Graph...
#
# [info] [gxf_executor.cpp:2240] Waiting for completion...
#
# [info] [greedy_scheduler.cpp:191] Scheduling 10 entities
#
# [2025-03-10 19:30:56,936] [INFO] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - No or invalid input path from the optional input port: None
#
# [2025-03-10 19:30:57,124] [INFO] (root) - Finding series for Selection named: highb
#
# [2025-03-10 19:30:57,124] [INFO] (root) - Searching study, : 1.3.6.1.4.1.14519.5.2.1.7311.5101.170561193612723093192571245493
#
#   # of series: 7
#
# [2025-03-10 19:30:57,124] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.212145009248667341607386363070
#
# [2025-03-10 19:30:57,124] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,124] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,124] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,124] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.473042633347744664896320600386
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.185507447168665319391310538903
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.278358228783511961204087191158
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.154156364083745277068656620138
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=3B 2000 w ERC SSh_DWI)|(?=AX DIFFUSION_CALC_BVAL_DFC_MIX)|(?=AX DWI)|(?=.*AX DWI (50,1500).*)|(?=Ax DWI BH)|(?=AX DWI_TRACEW_DFC_MIX)|(?=Axial FOCUS DWI 1400)|(?=b_1500 prostate)|(?=b_2000 prostate)|(?=DIFF bv1400)|(?=diff tra b 50 500 800 WIP511b alle spoelenCALC_BVAL)|(?=diffusie-3Scan-4bval_fsCALC_BVAL)|(?=DW_Synthetic: Ax DWI All B-50-800 Synthetic B-1400)|(?=.*DW_Synthetic: Ax Focus 50,500,800,1400,2000.*)|(?=DWI PROSTATE)|(?=DWI_5b_0_1500)|(?=DWI_b2000)|(?=DWI_b2000_new)|(?=DWI_b2000_new SENSE)|(?=DWI_b2000_NSA6 SENSE)|(?=ep2d_diff_b1400_new 32 measipat)|(?=ep2d_diff_tra_DYNDIST_MIXCALC_BVAL$)|(?=ep2d_diff_tra_DYNDISTCALC_BVAL)|(?=ep2d_diff_tra2x2_Noise0_FS_DYNDISTCALC_BVAL)|(?=ep2d-advdiff-3Scan-high bvalue 1400)|(?=sb_1500)|(?=sb_2000)|(?=sB1400)|(?=sb1500)|(?=sb-1500)|(?=sb1500 r5 only)|(?=sb-2000)|(?=sDWI_b_2000)|(?=sDWI_b2000))'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute SeriesDescription value: ep2d_diff_tra_DYNDIST_MIXCALC_BVAL
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Selected Series, UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.154156364083745277068656620138
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Finding series for Selection named: adc
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Searching study, : 1.3.6.1.4.1.14519.5.2.1.7311.5101.170561193612723093192571245493
#
#   # of series: 7
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.212145009248667341607386363070
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'ADC']
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,126] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.473042633347744664896320600386
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'ADC']
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,126] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.185507447168665319391310538903
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'ADC']
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,126] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'ADC']
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,126] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.278358228783511961204087191158
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'ADC']
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=ADC (10^-6 mm²/s))|(?=Apparent Diffusion Coefficient (mm2/s))|(?=AX DIFFUSION_ADC_DFC_MIX)|(?=.*AX DWI (50,1500)_ADC.*)|(?=AX DWI_ADC_DFC_MIX)|(?=b_1500 prostate_ADC)|(?=b_2000 prostate_ADC)|(?=d3B ADC 3B 750  ERC SSh_DWI FAST SENSE)|(?=dADC)|(?=dADC 0_1500)|(?=dADC 100 400 600)|(?=dADC 2)|(?=dADC 3)|(?=dADC ALL)|(?=dADC b 0 1000 2000)|(?=dADC from 0_1500)|(?=dADC from b0_600)|(?=dADC from B0-1500)|(?=dADC Map)|(?=dADC map 1)|(?=dADC MAP 2)|(?=dADC_1 axial)|(?=dADC_b375_750_1150)|(?=ddADC MAP)|(?=DIFF bv1400_ADC)|(?=diff tra b 50 500 800 WIP511b alle spoelen_ADC)|(?=diffusie-3Scan-4bval_fs_ADC)|(?=dReg - WIP SSh_DWI FAST SENSE)|(?=dSSh_DWI SENSE)|(?=DWI PROSTATE_ADC)|(?=dWIP 3B 600 w ERC SSh_DWI S2Ovs2)|(?=dWIP 3B ADC 3B 600 w/o ERC SSh_DWI FAST SENSE)|(?=dWIP SSh_DWI FAST SENSE)|(?=ep2d_diff_new 16 measipat_ADC)|(?=ep2d_DIFF_tra_b50_500_800_1400_alle_spoelen_ADC)|(?=ep2d_diff_tra_DYNDIST_ADC)|(?=ep2d_diff_tra_DYNDIST_MIX_ADC)|(?=ep2d_diff_tra2x2_Noise0_FS_DYNDIST_ADC)|(?=ep2d-advdiff-3Scan-4bval_spair_511b_ADC))'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute SeriesDescription value: ep2d_diff_tra_DYNDIST_MIX_ADC
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,127] [INFO] (root) - Selected Series, UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.278358228783511961204087191158
#
# [2025-03-10 19:30:57,127] [INFO] (root) - Finding series for Selection named: t2
#
# [2025-03-10 19:30:57,127] [INFO] (root) - Searching study, : 1.3.6.1.4.1.14519.5.2.1.7311.5101.170561193612723093192571245493
#
#   # of series: 7
#
# [2025-03-10 19:30:57,127] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.212145009248667341607386363070
#
# [2025-03-10 19:30:57,127] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,127] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,127] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
#
# [2025-03-10 19:30:57,127] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,127] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=AX T2)|(?=AX T2  6 NSA)|(?=AX T2  FAST)|(?=AX T2 . voxel 7x.8)|(?=AX T2 B1 Default)|(?=AX T2 CS)|(?=AX T2 cs 3.0)|(?=AX T2 FAST)|(?=AX T2 FRFSE)|(?=AX T2 N/S)|(?=AX T2 No sense)|(?=AX T2 NS)|(?=AX T2 NSA 3)|(?=AX T2 NSA 4)|(?=AX T2 NSA 5)|(?=AX T2 PROP)|(?=Ax T2 PROSTATE)|(?=AX T2 SMALL FOV)|(?=Ax T2 thin FRFSE)|(?=sT2 TSE ax no post)|(?=T2 AX)|(?=T2 AX SMALL FOV[*]? IF MOTION REPEAT[*]?)|(?=T2 AXIAL 3MM)|(?=T2 TRA 3mm)|(?=T2 TSE Ax)|(?=T2 TSE ax cs)|(?=T2 TSE ax hi)|(?=T2 TSE ax hi sense)|(?=T2 TSE ax no sense)|(?=T2 TSE ax NS)|(?=T2 TSE ax NSA 3)|(?=t2_tse_tra)|(?=t2_tse_tra_320_p2)|(?=t2_tse_tra_3mm _SFOV_TE 92)|(?=t2_tse_tra_Grappa3)|(?=T2W_TSE)|(?=T2W_TSE_ax)|(?=T2W_TSE_ax PSS Refoc 52)|(?=T2W_TSE_ax zoom PSS Refoc))'
#
# [2025-03-10 19:30:57,127] [INFO] (root) -     Series attribute SeriesDescription value: t2_tse_cor
#
# [2025-03-10 19:30:57,127] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.473042633347744664896320600386
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=AX T2)|(?=AX T2  6 NSA)|(?=AX T2  FAST)|(?=AX T2 . voxel 7x.8)|(?=AX T2 B1 Default)|(?=AX T2 CS)|(?=AX T2 cs 3.0)|(?=AX T2 FAST)|(?=AX T2 FRFSE)|(?=AX T2 N/S)|(?=AX T2 No sense)|(?=AX T2 NS)|(?=AX T2 NSA 3)|(?=AX T2 NSA 4)|(?=AX T2 NSA 5)|(?=AX T2 PROP)|(?=Ax T2 PROSTATE)|(?=AX T2 SMALL FOV)|(?=Ax T2 thin FRFSE)|(?=sT2 TSE ax no post)|(?=T2 AX)|(?=T2 AX SMALL FOV[*]? IF MOTION REPEAT[*]?)|(?=T2 AXIAL 3MM)|(?=T2 TRA 3mm)|(?=T2 TSE Ax)|(?=T2 TSE ax cs)|(?=T2 TSE ax hi)|(?=T2 TSE ax hi sense)|(?=T2 TSE ax no sense)|(?=T2 TSE ax NS)|(?=T2 TSE ax NSA 3)|(?=t2_tse_tra)|(?=t2_tse_tra_320_p2)|(?=t2_tse_tra_3mm _SFOV_TE 92)|(?=t2_tse_tra_Grappa3)|(?=T2W_TSE)|(?=T2W_TSE_ax)|(?=T2W_TSE_ax PSS Refoc 52)|(?=T2W_TSE_ax zoom PSS Refoc))'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute SeriesDescription value: t2_tse_sag
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.185507447168665319391310538903
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=AX T2)|(?=AX T2  6 NSA)|(?=AX T2  FAST)|(?=AX T2 . voxel 7x.8)|(?=AX T2 B1 Default)|(?=AX T2 CS)|(?=AX T2 cs 3.0)|(?=AX T2 FAST)|(?=AX T2 FRFSE)|(?=AX T2 N/S)|(?=AX T2 No sense)|(?=AX T2 NS)|(?=AX T2 NSA 3)|(?=AX T2 NSA 4)|(?=AX T2 NSA 5)|(?=AX T2 PROP)|(?=Ax T2 PROSTATE)|(?=AX T2 SMALL FOV)|(?=Ax T2 thin FRFSE)|(?=sT2 TSE ax no post)|(?=T2 AX)|(?=T2 AX SMALL FOV[*]? IF MOTION REPEAT[*]?)|(?=T2 AXIAL 3MM)|(?=T2 TRA 3mm)|(?=T2 TSE Ax)|(?=T2 TSE ax cs)|(?=T2 TSE ax hi)|(?=T2 TSE ax hi sense)|(?=T2 TSE ax no sense)|(?=T2 TSE ax NS)|(?=T2 TSE ax NSA 3)|(?=t2_tse_tra)|(?=t2_tse_tra_320_p2)|(?=t2_tse_tra_3mm _SFOV_TE 92)|(?=t2_tse_tra_Grappa3)|(?=T2W_TSE)|(?=T2W_TSE_ax)|(?=T2W_TSE_ax PSS Refoc 52)|(?=T2W_TSE_ax zoom PSS Refoc))'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute SeriesDescription value: tfl_3d PD ref_tra_1.5x1.5_t3
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=AX T2)|(?=AX T2  6 NSA)|(?=AX T2  FAST)|(?=AX T2 . voxel 7x.8)|(?=AX T2 B1 Default)|(?=AX T2 CS)|(?=AX T2 cs 3.0)|(?=AX T2 FAST)|(?=AX T2 FRFSE)|(?=AX T2 N/S)|(?=AX T2 No sense)|(?=AX T2 NS)|(?=AX T2 NSA 3)|(?=AX T2 NSA 4)|(?=AX T2 NSA 5)|(?=AX T2 PROP)|(?=Ax T2 PROSTATE)|(?=AX T2 SMALL FOV)|(?=Ax T2 thin FRFSE)|(?=sT2 TSE ax no post)|(?=T2 AX)|(?=T2 AX SMALL FOV[*]? IF MOTION REPEAT[*]?)|(?=T2 AXIAL 3MM)|(?=T2 TRA 3mm)|(?=T2 TSE Ax)|(?=T2 TSE ax cs)|(?=T2 TSE ax hi)|(?=T2 TSE ax hi sense)|(?=T2 TSE ax no sense)|(?=T2 TSE ax NS)|(?=T2 TSE ax NSA 3)|(?=t2_tse_tra)|(?=t2_tse_tra_320_p2)|(?=t2_tse_tra_3mm _SFOV_TE 92)|(?=t2_tse_tra_Grappa3)|(?=T2W_TSE)|(?=T2W_TSE_ax)|(?=T2W_TSE_ax PSS Refoc 52)|(?=T2W_TSE_ax zoom PSS Refoc))'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute SeriesDescription value: t2_tse_tra
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Selected Series, UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Converted Image object metadata:
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesDate: 20111018, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesTime: 115341.437000, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Modality: MR, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesDescription: t2_tse_tra, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - PatientPosition: FFS, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesNumber: 5, type <class 'int'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - row_pixel_spacing: 0.5, type <class 'float'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - col_pixel_spacing: 0.5, type <class 'float'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - depth_pixel_spacing: 4.244812427751082, type <class 'float'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - row_direction_cosine: [1.0, -1.99011e-10, 4.9619e-11], type <class 'list'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - col_direction_cosine: [2.051034e-10, 0.97029572703367, -0.2419218925608], type <class 'list'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - depth_direction_cosine: [1.4080733701821592e-17, 0.2419218925608, 0.97029572703367], type <class 'list'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - dicom_affine_transform: [[ 5.00000000e-01  1.02551700e-10  0.00000000e+00 -1.17913254e+02]
#
#  [-9.95055000e-11  4.85147864e-01  1.08864853e+00 -8.51499185e+01]
#
#  [ 2.48095000e-11 -1.20960946e-01  4.36633089e+00  1.28399916e+01]
#
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]], type <class 'numpy.ndarray'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - nifti_affine_transform: [[-5.00000000e-01 -1.02551700e-10 -0.00000000e+00  1.17913254e+02]
#
#  [ 9.95055000e-11 -4.85147864e-01 -1.08864853e+00  8.51499185e+01]
#
#  [ 2.48095000e-11 -1.20960946e-01  4.36633089e+00  1.28399916e+01]
#
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]], type <class 'numpy.ndarray'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.170561193612723093192571245493, type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyID: , type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyDate: 20111018, type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyTime: 113950.828000, type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyDescription: MR prostaat kanker detectie WDS_mc MCAPRODETW, type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - AccessionNumber: 1566645557835538, type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - selection_name: t2, type <class 'str'>
#
# [2025-03-10 19:30:57,160] [INFO] (Loaded image) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([384, 384, 19])
#
# Value range: (0.0, 1432.0)
#
# [2025-03-10 19:30:57,161] [INFO] (Channel-first image) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([1, 384, 384, 19])
#
# Value range: (0.0, 1432.0)
#
# [2025-03-10 19:30:57,276] [INFO] (Resampled and normalized image) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([1, 192, 193, 82])
#
# Value range: (-1.5097099542617798, 6.934730052947998)
#
# [2025-03-10 19:30:57,741] [INFO] (Model output) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([2, 192, 193, 82])
#
# Value range: (4.7445496420550626e-09, 1.0)
#
# [2025-03-10 19:30:57,858] [INFO] (Inverted output) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([2, 384, 384, 19])
#
# Value range: (2.0099241382354194e-08, 1.0)
#
# [2025-03-10 19:30:57,862] [INFO] (AsDiscrete output) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([1, 384, 384, 19])
#
# Value range: (0.0, 1.0)
#
# [2025-03-10 19:30:57,868] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Output Seg image numpy array shaped: (19, 384, 384)
#
# [2025-03-10 19:30:57,868] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Output Seg image pixel max value: 1
#
#
#
# Beginning organ segmentation...
#
# 2025-03-10 19:30:57,875 INFO image_writer.py:197 - writing: /var/holoscan/output/t2/t2.nii.gz
#
# 2025-03-10 19:30:57,999 INFO image_writer.py:197 - writing: /var/holoscan/output/adc/adc.nii.gz
#
# 2025-03-10 19:30:58,008 INFO image_writer.py:197 - writing: /var/holoscan/output/highb/highb.nii.gz
#
# 2025-03-10 19:30:58,015 INFO image_writer.py:197 - writing: /var/holoscan/output/organ/organ.nii.gz
#
#
#
# Beginning lesion segmentation...
#
# Loading input...
#
# [info] [greedy_scheduler.cpp:372] Scheduler stopped: Some entities are waiting for execution, but there are no periodic or async entities to get out of the deadlock.
#
# [info] [greedy_scheduler.cpp:401] Scheduler finished.
#
# [info] [gxf_executor.cpp:2243] Deactivating Graph...
#
# [info] [gxf_executor.cpp:2251] Graph execution finished.
#
# [info] [gxf_executor.cpp:294] Destroying context
#
# Inputs shape:  torch.Size([1, 3, 206, 186, 170])
#
# Inputs shape:  torch.Size([1, 3, 206, 186, 170])
#
# Inputs shape:  torch.Size([1, 3, 206, 186, 170])
#
# Inputs shape:  torch.Size([1, 3, 206, 186, 170])
#
# Inputs shape:  torch.Size([1, 3, 206, 186, 170])
#
# Created file: /var/holoscan/output/lesion/fold1_lesion_prob.nii.gz
#
# Created file: /var/holoscan/output/lesion/fold0_lesion_prob.nii.gz
#
# Created file: /var/holoscan/output/lesion/fold3_lesion_prob.nii.gz
#
# Created file: /var/holoscan/output/lesion/fold4_lesion_prob.nii.gz
#
# Created file: /var/holoscan/output/lesion/fold2_lesion_prob.nii.gz
#
# nda_prob min: 0.0
#
# nda_prob max: 1.0
#
# nda_prob mean: 0.003159677765710894
#
# nda_prob std: 0.05078099335586837
#
#
#
# Beginning lesion classification...
#
# Loading images...
#
# Resampling ADC/HIGHB to match T2...
#
# Resampling all channels to (0.5, 0.5, 0.5)...
#
# Combined volume shape: torch.Size([4, 384, 384, 163])
#
# Inputs shape:  (384, 384, 163)
#
# nda_resize_crops shape:  torch.Size([3, 64, 64, 64])
#
# {'Organ': 'Prostate', 'Major_Axis_Length': 253.97388926871932, 'Volume': 17872.75}
#
# predicted_value: 1
#
# {'Lesion_ID': 1, 'Major_Axis_Length': 32.67513188512687, 'Volume': 8581.5, 'PI_RADS': 3}
# [2025-03-10 15:31:18,706] [INFO] (common) - Container 'nervous_dijkstra'(3baab5796e76) exited.

# %%
# Load and display the output nifti segmentation on top of the t2 image
import os
import nibabel as nib
import matplotlib.pyplot as plt

t2_img = nib.load(os.path.join("output", "ProstateX-0004/t2/t2.nii.gz"))
organ_seg = nib.load(os.path.join("output", "ProstateX-0004/organ/organ.nii.gz"))
lesion_seg = nib.load(os.path.join("output", "ProstateX-0004/lesion/lesion_mask.nii.gz"))

t2_data = t2_img.get_fdata()
organ_data = organ_seg.get_fdata()
lesion_data = lesion_seg.get_fdata()

# Plot the t2 image, organ segmentation and lesion segmentation
slice = t2_data.shape[2] // 2
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.imshow(t2_data[:, :, slice].T, cmap="gray")
plt.title("T2 Image")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(organ_data[:, :, slice].T, cmap="gray")
plt.title("Organ Segmentation")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(lesion_data[:, :, slice].T, cmap="gray")
plt.title("Lesion Segmentation")
plt.axis("off")

plt.show()

# Create a single image with all the segmentations
plt.figure(figsize=(5, 5))
plt.imshow(t2_data[:, :, slice].T, cmap="gray")
plt.imshow(organ_data[:, :, slice].T, cmap="jet", alpha=0.5)
plt.imshow(lesion_data[:, :, slice].T, cmap="jet", alpha=0.5)
plt.title("T2 Image with Organ and Lesion Segmentations")
plt.axis("off")
plt.show()

# %%
# CONFIGURE THESE 
test_data_root = "test-data"                                         # root folder containing case subfolders
output_csv     = "series_description_latest_10_mar_2026.csv"       # output CSV path
app_path       = "prostate_mri_lesion_seg_app/app.py"                # path to app.py with Rules_T2/ADC/HIGHB

import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), "scripts"))
from fill_series_description_template import fill_series_description

fill_series_description(
    test_data_root=test_data_root,
    output_path=output_csv,
    app_path=app_path,
)
# Out:
# Auto-discovered 40 case(s) in test-data/
#   20201208_1debe8d041264ee1f4f8: 1 series found
#   20210406_c184b117e662d27b3ded: 1 series found
#   20211223_83e281a364289a3e3c1e: 1 series found
# /home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/pydicom/valuerep.py:440: UserWarning: The value length (20) exceeds the maximum length of 16 allowed for VR SH.
#   warn_and_log(msg)
#   20230221_272da2e6002c60fb7921: 13 series found
#   20230221_823319ef014cb44958c1: 7 series found
#   20230221_846949d736c10b2b1350: 13 series found
#   20230221_8f4a1eb6f46266320a70: 12 series found
#   20230221_ab0500f648159c7edf31: 13 series found
#   20230221_fc731afa9f772d79d3af: 13 series found
#   20230222_2f4df4a94ccd37425b48: 13 series found
#   20230222_3a6924f3936026543f19: 7 series found
#   20230222_3b7d0450e2a512ec0e92: 7 series found
#   20230222_520ac391d7946dde69d5: 11 series found
#   20230222_68bf25e98b00289cdb00: 10 series found
#   20230222_746ec0ed221211c7eced: 12 series found
#   20230222_cb66cb41b9efbe8cd217: 13 series found
#   20230222_ecdb6be112472ce42c74: 13 series found
#   20230223_4663bb845fe60d5e55a8: 10 series found
#   20230223_548530bb5b7523059fb6: 13 series found
#   20230223_8f6c60bf074349e7f155: 13 series found
#   20230223_b71e8540716fe1c41874: 13 series found
#   20230223_bc28d473c48987fdac9c: 12 series found
#   20230223_eed8dbaa06002275af56: 7 series found
#   20230224_57f45ff07453250f8b8d: 13 series found
#   20230314_c67bdead2890a4ebe191: 7 series found
#   20230315_1f558845c564f24ecbe7: 7 series found
#   20230315_445bf63f03f919b5e311: 8 series found
#   20230316_2f1f103cbba904beb5a1: 7 series found
#   20230316_649d127395cd81ca4195: 12 series found
#   20230316_8b38fee3f383e6321ddb: 7 series found
#   20230316_f273a56e616a27b576ea: 13 series found
#   20230317_0ca6225f3d0c7533efd5: 7 series found
#   20230317_3cd7efd737524c725c2f: 13 series found
#   ProstateX-0000: 52 series found
#   ProstateX-0001: 56 series found
#   ProstateX-0004: 7 series found
#   sgh_data_patient_1: 11 series found
#   sgh_data_patient_2: 8 series found
#   sgh_data_patient_3: 10 series found
#   sgh_data_patient_4: 13 series found
#
# Wrote 479 series to: series_description_latest_10_mar_2026.csv
# 'series_description_latest_10_mar_2026.csv'

# %%
"""
DICOM Metadata Compatibility Diagnostic
========================================
Checks all test-data cases for:
  1. (0020,0010) StudyID — required by rt_utils for RTSTRUCT generation
  2. Related de-identification tags for Dr. Anh / Jun Yan investigation
  3. Per-series slice counts to flag series too thin for volume reconstruction

Findings so far:
  - ProstateX:  StudyID tag IS present (empty string '') → rt_utils works
  - SGH data:   StudyID tag is COMPLETELY MISSING       → rt_utils crashes
  - Dr. Anh says (0020,0010) StudyID should be a hash of AccessionNumber
    if de-id went correctly. Its absence suggests the de-id tool stripped
    it instead of hashing it.
"""

import os
import pydicom
from collections import defaultdict
from pathlib import Path

TEST_ROOT = Path("test-data")

TAGS_TO_CHECK = [
    ("StudyID",                0x0020, 0x0010, "REQUIRED by rt_utils for RTSTRUCT"),
    ("AccessionNumber",        0x0008, 0x0050, "Should hash to StudyID per de-id"),
    ("PatientID",              0x0010, 0x0020, "De-id: should be hashed"),
    ("PatientName",            0x0010, 0x0010, "De-id: should be hashed"),
    ("StudyInstanceUID",       0x0020, 0x000D, "Study-level UID"),
    ("SeriesInstanceUID",      0x0020, 0x000E, "Series-level UID"),
    ("ImageType",              0x0008, 0x0008, "Critical for series selection rules"),
    ("SeriesDescription",      0x0008, 0x103E, "Critical for series selection rules"),
    ("InstitutionName",        0x0008, 0x0080, "De-id: should be removed/hashed"),
    ("ReferringPhysicianName", 0x0008, 0x0090, "De-id: should be removed/hashed"),
]

SEPARATOR = "=" * 100

cases = sorted([d for d in os.listdir(TEST_ROOT) if (TEST_ROOT / d).is_dir()])

# ─── Part 1: StudyID presence summary ───────────────────────────────────────
print(SEPARATOR)
print("PART 1: StudyID (0020,0010) Presence — Summary Across All Cases")
print(SEPARATOR)
print(f"{'Case':<25} {'StudyID Present?':>17} {'StudyID Value':<25} {'AccessionNumber':<25}")
print("-" * 100)

case_sample_files = {}
for case in cases:
    case_path = TEST_ROOT / case
    sample_file = None
    for dirpath, _, filenames in os.walk(case_path):
        for fn in sorted(filenames):
            if fn.lower().endswith(".dcm"):
                sample_file = os.path.join(dirpath, fn)
                break
        if sample_file:
            break
    if not sample_file:
        continue

    ds = pydicom.dcmread(sample_file, stop_before_pixels=True, force=True)
    case_sample_files[case] = (sample_file, ds)

    tag_present = (0x0020, 0x0010) in ds
    study_id = getattr(ds, "StudyID", None)
    accession = getattr(ds, "AccessionNumber", None)

    status = "YES" if tag_present else "** MISSING **"
    val_display = repr(study_id) if study_id is not None else "N/A (tag absent)"
    print(f"{case:<25} {status:>17} {val_display:<25} {accession or 'N/A':<25}")

# ─── Part 2: Full tag audit per case ────────────────────────────────────────
print(f"\n{SEPARATOR}")
print("PART 2: Full DICOM Tag Audit (one sample file per case)")
print(SEPARATOR)

for case in cases:
    if case not in case_sample_files:
        continue
    sample_file, ds = case_sample_files[case]
    fn = os.path.basename(sample_file)
    print(f"\n--- {case} (sample: {fn}) ---")
    print(f"  {'Tag':12s} {'Keyword':<30s} {'Present':>8s}  {'Value':<50s}  Note")
    print(f"  {'-'*12} {'-'*30} {'-'*8}  {'-'*50}  {'-'*30}")
    for name, g, e, note in TAGS_TO_CHECK:
        present = (g, e) in ds
        val = getattr(ds, name, None)
        val_str = repr(val) if val is not None else "N/A"
        if len(val_str) > 48:
            val_str = val_str[:45] + "..."
        flag = "YES" if present else "MISSING"
        alert = " <<<< ISSUE" if (not present and "REQUIRED" in note) else ""
        print(f"  ({g:04X},{e:04X}) {name:<30s} {flag:>8s}  {val_str:<50s}  {note}{alert}")

# ─── Part 3: Per-series slice counts ────────────────────────────────────────
print(f"\n{SEPARATOR}")
print("PART 3: Per-Series Slice Counts (flags series with < 3 slices)")
print(SEPARATOR)

MIN_SLICES_FOR_AFFINE = 2
MIN_SLICES_FOR_MODEL = 5

for case in cases:
    case_path = TEST_ROOT / case
    series_slices = defaultdict(int)
    series_desc = {}
    series_image_type = {}

    for dirpath, _, filenames in os.walk(case_path):
        for fn in filenames:
            if not fn.lower().endswith(".dcm"):
                continue
            fp = os.path.join(dirpath, fn)
            try:
                ds = pydicom.dcmread(fp, stop_before_pixels=True, force=True)
                uid = str(getattr(ds, "SeriesInstanceUID", "unknown"))
                series_slices[uid] += 1
                series_desc[uid] = str(getattr(ds, "SeriesDescription", "N/A"))
                it = getattr(ds, "ImageType", None)
                series_image_type[uid] = str(it) if it else "None"
            except Exception:
                pass

    total = sum(series_slices.values())
    print(f"\n--- {case} --- ({total} DCMs, {len(series_slices)} series)")
    print(f"  {'Slices':>6s}  {'Flag':>12s}  {'SeriesDescription':<55s}  ImageType")
    print(f"  {'-'*6}  {'-'*12}  {'-'*55}  {'-'*50}")

    for uid, count in sorted(series_slices.items(), key=lambda x: -x[1]):
        desc = series_desc.get(uid, "?")
        itype = series_image_type.get(uid, "?")
        if len(itype) > 48:
            itype = itype[:45] + "..."
        if count < MIN_SLICES_FOR_AFFINE:
            flag = "** CRASH **"
        elif count < MIN_SLICES_FOR_MODEL:
            flag = "LOW"
        else:
            flag = "OK"
        print(f"  {count:>6d}  {flag:>12s}  {desc:<55s}  {itype}")

# ─── Part 4: Recommendation for Dr. Anh ─────────────────────────────────────
print(f"\n{SEPARATOR}")
print("PART 4: Findings & Recommendation for Dr. Anh / Jun Yan")
print(SEPARATOR)
print("""
FINDING: (0020,0010) StudyID tag is COMPLETELY ABSENT from all SGH DICOM files.
         ProstateX data has StudyID present (as empty string '').

         The de-identification process for SGH data appears to have STRIPPED
         the StudyID tag entirely instead of replacing it with a hash of the
         AccessionNumber.

IMPACT:  rt_utils (used for RTSTRUCT generation) calls pydicom's FileDataset
         which expects StudyID to exist. When missing, it raises:
           'FileDataset' object has no attribute 'StudyID'

AFFECTED PATIENTS:
  - sgh_data_patient_1  (AccessionNumber: 8f4a1eb6f46266320a70)
  - sgh_data_patient_2  (AccessionNumber: 823319ef014cb44958c1)
  - sgh_data_patient_3  (AccessionNumber: 68bf25e98b00289cdb00)
  - sgh_data_patient_4  (AccessionNumber: eed80f7e38dd92b9cb9d)

ACTION NEEDED:
  1. Share any SGH DICOM study with Jun Yan to confirm this is a systemic
     de-id issue (the AccessionNumber values above can identify the studies).
  2. Jun Yan should fix the de-id pipeline to HASH StudyID rather than strip it.
  3. As a workaround, our app can inject a synthetic StudyID (hash of
     AccessionNumber) at runtime before RTSTRUCT generation.
""")
# Out:
# ====================================================================================================
# PART 1: StudyID (0020,0010) Presence — Summary Across All Cases
# ====================================================================================================
# Case                       StudyID Present? StudyID Value             AccessionNumber
# ----------------------------------------------------------------------------------------------------
# ProstateX-0000                          YES ''                        2037145102504919
# ProstateX-0001                          YES ''                        2011979747735411
# ProstateX-0004                          YES ''                        1566645557835538
# sgh_data_patient_1            ** MISSING ** N/A (tag absent)          8f4a1eb6f46266320a70
# sgh_data_patient_2            ** MISSING ** N/A (tag absent)          823319ef014cb44958c1
# sgh_data_patient_3            ** MISSING ** N/A (tag absent)          68bf25e98b00289cdb00
# sgh_data_patient_4            ** MISSING ** N/A (tag absent)          eed80f7e38dd92b9cb9d
#
# ====================================================================================================
# PART 2: Full DICOM Tag Audit (one sample file per case)
# ====================================================================================================
#
# --- ProstateX-0000 (sample: 1-01.dcm) ---
#   Tag          Keyword                         Present  Value                                               Note
#   ------------ ------------------------------ --------  --------------------------------------------------  ------------------------------
#   (0020,0010) StudyID                             YES  ''                                                  REQUIRED by rt_utils for RTSTRUCT
#   (0008,0050) AccessionNumber                     YES  '2037145102504919'                                  Should hash to StudyID per de-id
#   (0010,0020) PatientID                           YES  'ProstateX-0000'                                    De-id: should be hashed
#   (0010,0010) PatientName                         YES  'ProstateX-0000'                                    De-id: should be hashed
#   (0020,000D) StudyInstanceUID                    YES  '1.3.6.1.4.1.14519.5.2.1.7311.5101.1583235471...    Study-level UID
#   (0020,000E) SeriesInstanceUID                   YES  '1.3.6.1.4.1.14519.5.2.1.7311.5101.9678206092...    Series-level UID
#   (0008,0008) ImageType                           YES  ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']               Critical for series selection rules
#   (0008,103E) SeriesDescription                   YES  'tfl_dyn_fast_tra_1.5x1.5_t3.5sec'                  Critical for series selection rules
#   (0008,0080) InstitutionName                 MISSING  N/A                                                 De-id: should be removed/hashed
#   (0008,0090) ReferringPhysicianName          MISSING  N/A                                                 De-id: should be removed/hashed
#
# --- ProstateX-0001 (sample: 1-01.dcm) ---
#   Tag          Keyword                         Present  Value                                               Note
#   ------------ ------------------------------ --------  --------------------------------------------------  ------------------------------
#   (0020,0010) StudyID                             YES  ''                                                  REQUIRED by rt_utils for RTSTRUCT
#   (0008,0050) AccessionNumber                     YES  '2011979747735411'                                  Should hash to StudyID per de-id
#   (0010,0020) PatientID                           YES  'ProstateX-0001'                                    De-id: should be hashed
#   (0010,0010) PatientName                         YES  'ProstateX-0001'                                    De-id: should be hashed
#   (0020,000D) StudyInstanceUID                    YES  '1.3.6.1.4.1.14519.5.2.1.7311.5101.2047863911...    Study-level UID
#   (0020,000E) SeriesInstanceUID                   YES  '1.3.6.1.4.1.14519.5.2.1.7311.5101.9666477192...    Series-level UID
#   (0008,0008) ImageType                           YES  ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']               Critical for series selection rules
#   (0008,103E) SeriesDescription                   YES  'tfl_dyn_fast_tra_1.5x1.5_t3.5sec'                  Critical for series selection rules
#   (0008,0080) InstitutionName                 MISSING  N/A                                                 De-id: should be removed/hashed
#   (0008,0090) ReferringPhysicianName          MISSING  N/A                                                 De-id: should be removed/hashed
#
# --- ProstateX-0004 (sample: 1-01.dcm) ---
#   Tag          Keyword                         Present  Value                                               Note
#   ------------ ------------------------------ --------  --------------------------------------------------  ------------------------------
#   (0020,0010) StudyID                             YES  ''                                                  REQUIRED by rt_utils for RTSTRUCT
#   (0008,0050) AccessionNumber                     YES  '1566645557835538'                                  Should hash to StudyID per de-id
#   (0010,0020) PatientID                           YES  'ProstateX-0004'                                    De-id: should be hashed
#   (0010,0010) PatientName                         YES  'ProstateX-0004'                                    De-id: should be hashed
#   (0020,000D) StudyInstanceUID                    YES  '1.3.6.1.4.1.14519.5.2.1.7311.5101.1705611936...    Study-level UID
#   (0020,000E) SeriesInstanceUID                   YES  '1.3.6.1.4.1.14519.5.2.1.7311.5101.4730426333...    Series-level UID
#   (0008,0008) ImageType                           YES  ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']       Critical for series selection rules
#   (0008,103E) SeriesDescription                   YES  't2_tse_sag'                                        Critical for series selection rules
#   (0008,0080) InstitutionName                 MISSING  N/A                                                 De-id: should be removed/hashed
#   (0008,0090) ReferringPhysicianName          MISSING  N/A                                                 De-id: should be removed/hashed
#
# --- sgh_data_patient_1 (sample: MR1.2.826.0.1.3680043.8.498.10734312113599673148963377622470857268.dcm) ---
#   Tag          Keyword                         Present  Value                                               Note
#   ------------ ------------------------------ --------  --------------------------------------------------  ------------------------------
#   (0020,0010) StudyID                         MISSING  N/A                                                 REQUIRED by rt_utils for RTSTRUCT <<<< ISSUE
#   (0008,0050) AccessionNumber                     YES  '8f4a1eb6f46266320a70'                              Should hash to StudyID per de-id
#   (0010,0020) PatientID                           YES  '8f4a1eb6f46266320a70'                              De-id: should be hashed
#   (0010,0010) PatientName                         YES  '277568990b437ad3ff67'                              De-id: should be hashed
#   (0020,000D) StudyInstanceUID                    YES  '1.2.826.0.1.3680043.8.498.114963869860294765...    Study-level UID
#   (0020,000E) SeriesInstanceUID                   YES  '1.2.826.0.1.3680043.8.498.339357317557236473...    Series-level UID
#   (0008,0008) ImageType                           YES  ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']          Critical for series selection rules
#   (0008,103E) SeriesDescription                   YES  'et2_tse_tra'                                       Critical for series selection rules
#   (0008,0080) InstitutionName                 MISSING  N/A                                                 De-id: should be removed/hashed
#   (0008,0090) ReferringPhysicianName          MISSING  N/A                                                 De-id: should be removed/hashed
#
# --- sgh_data_patient_2 (sample: MR1.2.826.0.1.3680043.8.498.35711031930961759285923600384476209700.dcm) ---
#   Tag          Keyword                         Present  Value                                               Note
#   ------------ ------------------------------ --------  --------------------------------------------------  ------------------------------
#   (0020,0010) StudyID                         MISSING  N/A                                                 REQUIRED by rt_utils for RTSTRUCT <<<< ISSUE
#   (0008,0050) AccessionNumber                     YES  '823319ef014cb44958c1'                              Should hash to StudyID per de-id
#   (0010,0020) PatientID                           YES  '823319ef014cb44958c1'                              De-id: should be hashed
#   (0010,0010) PatientName                         YES  '233b77e4729ae2f44335'                              De-id: should be hashed
#   (0020,000D) StudyInstanceUID                    YES  '1.2.826.0.1.3680043.8.498.979483052336672608...    Study-level UID
#   (0020,000E) SeriesInstanceUID                   YES  '1.2.826.0.1.3680043.8.498.132350489376082506...    Series-level UID
#   (0008,0008) ImageType                           YES  ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']       Critical for series selection rules
#   (0008,103E) SeriesDescription                   YES  'AX_t1_tse'                                         Critical for series selection rules
#   (0008,0080) InstitutionName                 MISSING  N/A                                                 De-id: should be removed/hashed
#   (0008,0090) ReferringPhysicianName          MISSING  N/A                                                 De-id: should be removed/hashed
#
# --- sgh_data_patient_3 (sample: MR1.2.826.0.1.3680043.8.498.10180159290116796110691712851318320146.dcm) ---
#   Tag          Keyword                         Present  Value                                               Note
#   ------------ ------------------------------ --------  --------------------------------------------------  ------------------------------
#   (0020,0010) StudyID                         MISSING  N/A                                                 REQUIRED by rt_utils for RTSTRUCT <<<< ISSUE
#   (0008,0050) AccessionNumber                     YES  '68bf25e98b00289cdb00'                              Should hash to StudyID per de-id
#   (0010,0020) PatientID                           YES  '68bf25e98b00289cdb00'                              De-id: should be hashed
#   (0010,0010) PatientName                         YES  'c1a9399dd1ae0aa91669'                              De-id: should be hashed
#   (0020,000D) StudyInstanceUID                    YES  '1.2.826.0.1.3680043.8.498.103165544608040046...    Study-level UID
#   (0020,000E) SeriesInstanceUID                   YES  '1.2.826.0.1.3680043.8.498.782808828078663125...    Series-level UID
#   (0008,0008) ImageType                           YES  ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW',...    Critical for series selection rules
#   (0008,103E) SeriesDescription                   YES  'ep2d_diff_zoomit_b50_500_1000_1800_tra_TRACEW'     Critical for series selection rules
#   (0008,0080) InstitutionName                 MISSING  N/A                                                 De-id: should be removed/hashed
#   (0008,0090) ReferringPhysicianName          MISSING  N/A                                                 De-id: should be removed/hashed
#
# --- sgh_data_patient_4 (sample: MR1.2.826.0.1.3680043.8.498.10361081385997568753777684292610004475.dcm) ---
#   Tag          Keyword                         Present  Value                                               Note
#   ------------ ------------------------------ --------  --------------------------------------------------  ------------------------------
#   (0020,0010) StudyID                         MISSING  N/A                                                 REQUIRED by rt_utils for RTSTRUCT <<<< ISSUE
#   (0008,0050) AccessionNumber                     YES  'eed80f7e38dd92b9cb9d'                              Should hash to StudyID per de-id
#   (0010,0020) PatientID                           YES  'eed80f7e38dd92b9cb9d'                              De-id: should be hashed
#   (0010,0010) PatientName                         YES  '565bcf5ee18a3492ab59'                              De-id: should be hashed
#   (0020,000D) StudyInstanceUID                    YES  '1.2.826.0.1.3680043.8.498.839771460235709365...    Study-level UID
#   (0020,000E) SeriesInstanceUID                   YES  '1.2.826.0.1.3680043.8.498.451574015008641908...    Series-level UID
#   (0008,0008) ImageType                           YES  ['ORIGINAL', 'PRIMARY', 'M_FFE', 'M', 'FFE']        Critical for series selection rules
#   (0008,103E) SeriesDescription                   YES  'e-THRIVE_tra_fs+c_wholepelvis'                     Critical for series selection rules
#   (0008,0080) InstitutionName                 MISSING  N/A                                                 De-id: should be removed/hashed
#   (0008,0090) ReferringPhysicianName          MISSING  N/A                                                 De-id: should be removed/hashed
#
# ====================================================================================================
# PART 3: Per-Series Slice Counts (flags series with < 3 slices)
# ====================================================================================================
# /home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/pydicom/valuerep.py:440: UserWarning: The value length (20) exceeds the maximum length of 16 allowed for VR SH.
#   warn_and_log(msg)
# --- ProstateX-0000 --- (884 DCMs, 52 series)
#   Slices          Flag  SeriesDescription                                        ImageType
#   ------  ------------  -------------------------------------------------------  --------------------------------------------------
#       57            OK  ep2d_diff_tra_DYNDIST                                    ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW',...
#       19            OK  ep2d_diff_tra_DYNDISTCALC_BVAL                           ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW',...
#       19            OK  t2_tse_sag                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#       19            OK  ep2d_diff_tra_DYNDIST_ADC                                ['DERIVED', 'PRIMARY', 'DIFFUSION', 'ADC', 'D...
#       19            OK  t2_tse_tra                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_3d PD ref_tra_1.5x1.5_t3                             ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       15            OK  t2_tse_cor                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#
# --- ProstateX-0001 --- (932 DCMs, 56 series)
#   Slices          Flag  SeriesDescription                                        ImageType
#   ------  ------------  -------------------------------------------------------  --------------------------------------------------
#       57            OK  ep2d_diff_tra_DYNDIST_MIX                                ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW',...
#       19            OK  t2_tse_sag                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#       19            OK  ep2d_diff_tra_DYNDIST_MIXCALC_BVAL                       ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW',...
#       19            OK  t2_tse_tra                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#       19            OK  ep2d_diff_tra_DYNDIST_MIX_ADC                            ['DERIVED', 'PRIMARY', 'DIFFUSION', 'ADC', 'D...
#       19            OK  t2_tse_tra                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_3d PD ref_tra_1.5x1.5_t3                             ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       16            OK  tfl_dyn_fast_tra_1.5x1.5_t3.5sec                         ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#       15            OK  t2_tse_cor                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#       13            OK  t2_localizer                                             ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#       13            OK  t2_localizer                                             ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#        3           LOW  t2_loc sag                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#
# --- ProstateX-0004 --- (170 DCMs, 7 series)
#   Slices          Flag  SeriesDescription                                        ImageType
#   ------  ------------  -------------------------------------------------------  --------------------------------------------------
#       57            OK  ep2d_diff_tra_DYNDIST_MIX                                ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW',...
#       21            OK  t2_tse_cor                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#       19            OK  t2_tse_sag                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#       19            OK  ep2d_diff_tra_DYNDIST_MIXCALC_BVAL                       ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW',...
#       19            OK  ep2d_diff_tra_DYNDIST_MIX_ADC                            ['DERIVED', 'PRIMARY', 'DIFFUSION', 'ADC', 'D...
#       19            OK  t2_tse_tra                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#       16            OK  tfl_3d PD ref_tra_1.5x1.5_t3                             ['ORIGINAL', 'PRIMARY', 'M', 'DIS2D']
#
# --- sgh_data_patient_1 --- (51 DCMs, 11 series)
#   Slices          Flag  SeriesDescription                                        ImageType
#   ------  ------------  -------------------------------------------------------  --------------------------------------------------
#       19            OK  dep2d_diff_3scan_trace_RL                                ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        5            OK  et2_tse_tra                                              ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        4           LOW  et2_tse_cor                                              ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        4           LOW  et2_tse_tra obl                                          ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        4           LOW  et1_tse_tra                                              ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        4           LOW  et2_tse_tra_sfs_whole_pelvis                             ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        3           LOW  eTHRIVE+c wholepelvis                                    ['ORIGINAL', 'PRIMARY', 'M_FFE', 'M', 'FFE']
#        3           LOW  ddep2d_diff_ADC                                          ['ORIGINAL', 'PRIMARY', 'ADC_UNSPECIFIED', 'A...
#        2           LOW  et1_tse_tra_whole_pelvis                                 ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        2           LOW  et2_tse_sag_multivane                                    ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        1   ** CRASH **  SURVEY                                                   ['ORIGINAL', 'PRIMARY', 'M_FFE', 'M', 'FFE']
#
# --- sgh_data_patient_2 --- (42 DCMs, 8 series)
#   Slices          Flag  SeriesDescription                                        ImageType
#   ------  ------------  -------------------------------------------------------  --------------------------------------------------
#       13            OK  AX DWI_diff_b50- b500-b1000-b1800_TRACEW                 ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW',...
#        7            OK  AX_T1_vibe_Whole Pelvis POST CONTRAST_W                  ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'WATER',...
#        5            OK  AX_t2_tse                                                ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#        4           LOW  AX_t1_tse                                                ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#        4           LOW  SAG_t2_tse                                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#        3           LOW  AX_T2 FS whole pelvis                                    ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
#        3           LOW  AX DWI_diff_b50- b500-b1000-b1800_ADC                    ['DERIVED', 'PRIMARY', 'DIFFUSION', 'ADC', 'D...
#        3           LOW  AX_t1_tse whole pelvis                                   ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D']
#
# --- sgh_data_patient_3 --- (54 DCMs, 10 series)
#   Slices          Flag  SeriesDescription                                        ImageType
#   ------  ------------  -------------------------------------------------------  --------------------------------------------------
#       21            OK  ep2d_diff_zoomit_b50_500_1000_1800_tra_TRACEW            ['DERIVED', 'PRIMARY', 'DIFFUSION', 'TRACEW',...
#        7            OK  t2_tse_sag_fast-blade                                    ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D',...
#        6            OK  t2_tse_tra_fast-blade                                    ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D',...
#        6            OK  t2_tse_tra_fs_whole_pelvis p4                            ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D',...
#        5            OK  t1_tse_tra p2                                            ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D',...
#        3           LOW  t1_tse_tra_whole_pelvis p4                               ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D',...
#        2           LOW  t2_tse_tra_obl_fast-blade                                ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D',...
#        2           LOW  t2_tse_cor_fast-blade                                    ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D',...
#        1   ** CRASH **  ep2d_diff_zoomit_b50_500_1000_1800_tra_ADC               ['DERIVED', 'PRIMARY', 'DIFFUSION', 'ADC', 'N...
#        1   ** CRASH **  localizer                                                ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D',...
#
# --- sgh_data_patient_4 --- (49 DCMs, 13 series)
#   Slices          Flag  SeriesDescription                                        ImageType
#   ------  ------------  -------------------------------------------------------  --------------------------------------------------
#        9            OK  e-THRIVE_tra_fs+c_wholepelvis                            ['ORIGINAL', 'PRIMARY', 'M_FFE', 'M', 'FFE']
#        9            OK  dwi_zoom_b0_500_1000                                     ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        5            OK  dReg - dwi_zoom_b0_500_1000_ADC                          ['ORIGINAL', 'PRIMARY', 'ADC_UNSPECIFIED', 'A...
#        4           LOW  t2_tse_tra_pelvis_fs                                     ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        3           LOW  dwi_zoom_b1800                                           ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        3           LOW  ee-THRIVE_tra_fs                                         ['ORIGINAL', 'PRIMARY', 'M_FFE', 'M', 'FFE']
#        3           LOW  t1_tra_tra_pelvis                                        ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        3           LOW  et1_tse_tra                                              None
#        3           LOW  et2_tse_sag                                              ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        2           LOW  et2_tse_cor                                              ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        2           LOW  eet2_tse_tra_obl                                         ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#        2           LOW  SURVEY_BFFE                                              ['ORIGINAL', 'PRIMARY', 'M_FFE', 'M', 'FFE']
#        1   ** CRASH **  et2_tse_tra                                              ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
#
# ====================================================================================================
# PART 4: Findings & Recommendation for Dr. Anh / Jun Yan
# ====================================================================================================
#
# FINDING: (0020,0010) StudyID tag is COMPLETELY ABSENT from all SGH DICOM files.
#          ProstateX data has StudyID present (as empty string '').
#
#          The de-identification process for SGH data appears to have STRIPPED
#          the StudyID tag entirely instead of replacing it with a hash of the
#          AccessionNumber.
#
# IMPACT:  rt_utils (used for RTSTRUCT generation) calls pydicom's FileDataset
#          which expects StudyID to exist. When missing, it raises:
#            'FileDataset' object has no attribute 'StudyID'
#
# AFFECTED PATIENTS:
#   - sgh_data_patient_1  (AccessionNumber: 8f4a1eb6f46266320a70)
#   - sgh_data_patient_2  (AccessionNumber: 823319ef014cb44958c1)
#   - sgh_data_patient_3  (AccessionNumber: 68bf25e98b00289cdb00)
#   - sgh_data_patient_4  (AccessionNumber: eed80f7e38dd92b9cb9d)
#
# ACTION NEEDED:
#   1. Share any SGH DICOM study with Jun Yan to confirm this is a systemic
#      de-id issue (the AccessionNumber values above can identify the studies).
#   2. Jun Yan should fix the de-id pipeline to HASH StudyID rather than strip it.
#   3. As a workaround, our app can inject a synthetic StudyID (hash of
#      AccessionNumber) at runtime before RTSTRUCT generation.
