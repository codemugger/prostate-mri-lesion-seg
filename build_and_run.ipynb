# %% [markdown]
# Install MONAI Deploy App SDK and dependencies

# %%
# %pip install -r prostate_mri_lesion_seg_app/requirements.txt

# %% [markdown]
# Download models and test data

# %%
# Download the following folder (ProstateX-0004) and place in test-data/
# https://drive.google.com/drive/folders/1besSncSLlbeiv7UWveRJoOYQXOzu3JkU?usp=drive_link

# Download the following folder of models and place in prostate_lesion_seg_app/models
# https://drive.google.com/drive/folders/1EpjrlzEdV7CcaCYqGTIEzOapamP4Ag6M?usp=drive_link

# %%
import os 
os.getcwd()
# Out:
# '/home/anson/work/research-contributions/prostate-mri-lesion-seg'

# %% [markdown]
# Test application locally (non-containerized)

# %%
# %%bash
#
# ./scripts/test_local.sh -i test-data/ProstateX-0004/ -o output/ -m models/
# Out:
# Running local test on GPU...
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[2], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '\n./scripts/test_local.sh -i test-data/ProstateX-0004/ -o output/ -m models/\n')
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2547, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2546     args = (magic_arg_s, cell)
# -> 2547     result = fn(*args, **kwargs)
#    2549 # The code below prevents the output from being displayed
#    2550 # when using magics with decorator @output_can_be_silenced
#    2551 # when the last Python token in the expression is a ';'.
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/IPython/core/magics/script.py:159, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     158     line = script
# --> 159 return self.shebang(line, cell)
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/IPython/core/magics/script.py:327, in ScriptMagics.shebang(self, line, cell)
#     326 if args.raise_error:
# --> 327     raise CalledProcessError(p.returncode, cell) from None
#     328 else:
#
# <class 'str'>: (<class 'TypeError'>, TypeError('%d format: a real number is required, not NoneType'))
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2187, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2184         traceback.print_exc()
#    2185         return None
# -> 2187     self._showtraceback(etype, value, stb)
#    2188 if self.call_pdb:
#    2189     # drop into debugger
#    2190     self.debugger(force=True)
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/ipykernel/zmqshell.py:559, in ZMQInteractiveShell._showtraceback(self, etype, evalue, stb)
#     553 sys.stdout.flush()
#     554 sys.stderr.flush()
#     556 exc_content = {
#     557     "traceback": stb,
#     558     "ename": str(etype.__name__),
# --> 559     "evalue": str(evalue),
#     560 }
#     562 dh = self.displayhook
#     563 # Send exception info over pub socket for other clients than the caller
#     564 # to pick up
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/subprocess.py:148, in CalledProcessError.__str__(self)
#     145         return "Command '%s' died with unknown signal %d." % (
#     146                 self.cmd, -self.returncode)
#     147 else:
# --> 148     return "Command '%s' returned non-zero exit status %d." % (
#     149             self.cmd, self.returncode)
#
# TypeError: %d format: a real number is required, not NoneType
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3384, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3380 exec_count = self.execution_count
#    3381 if result.error_in_exec:
#    3382     # Store formatted traceback and error details
#    3383     self.history_manager.exceptions[exec_count] = (
# -> 3384         self._format_exception_for_storage(result.error_in_exec)
#    3385     )
#    3387 # Each cell is a *single* input, regardless of how many lines it has
#    3388 self.execution_count += 1
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3445, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3441         except Exception:
#    3442             # In case formatting fails, fallback to Python's built-in formatting.
#    3443             stb = traceback.format_exception(etype, evalue, tb)
# -> 3445 return {"ename": etype.__name__, "evalue": str(evalue), "traceback": stb}
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/subprocess.py:148, in CalledProcessError.__str__(self)
#     145         return "Command '%s' died with unknown signal %d." % (
#     146                 self.cmd, -self.returncode)
#     147 else:
# --> 148     return "Command '%s' returned non-zero exit status %d." % (
#     149             self.cmd, self.returncode)
#
# TypeError: %d format: a real number is required, not NoneType
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/anson/work/research-contributions/prostate-mri-lesion-seg/scripts/../prostate_mri_lesion_seg_app/__main__.py", line 57, in <module>
#     from app import AIProstateLesionSegApp
#   File "/home/anson/work/research-contributions/prostate-mri-lesion-seg/scripts/../prostate_mri_lesion_seg_app/app.py", line 61, in <module>
#     from monai.deploy.conditions import CountCondition
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/__init__.py", line 83, in <module>
#     from .utils.module import load_submodules  # noqa: E402
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/utils/__init__.py", line 16, in <module>
#     from .deprecate_utils import DeprecatedError, deprecated, deprecated_arg, deprecated_arg_default
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/utils/deprecate_utils.py", line 22, in <module>
#     from monai.utils.module import version_leq
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/monai/utils/module.py", line 30, in <module>
#     import torch
#   File "/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/torch/__init__.py", line 409, in <module>
#     from torch._C import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 216, in _lock_unlock_module
# KeyboardInterrupt

# %%
# %%bash
#
# bash ./scripts/test_batch.sh -i test-data/ -o output/ -m models/
# Out:
# Batch processing patients under: test-data/
# Writing per-patient outputs under: output/
# Using model directory: models/
# ----------------------------------------
# Processing patient: ProstateX-0000
#   Input:  test-data//ProstateX-0000/
#   Output: output//ProstateX-0000
#   Running on GPU...
# [2025-12-11 15:51:52,204] [INFO] (root) - Parsed args: Namespace(log_level=None, input=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000'), output=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0000'), model=PosixPath('/home/anson/work/research-contributions/prostate-mri-lesion-seg/models'), workdir=None, argv=['/home/anson/work/research-contributions/prostate-mri-lesion-seg/scripts/../prostate_mri_lesion_seg_app', '-i', 'test-data//ProstateX-0000/', '-o', 'output//ProstateX-0000', '-m', 'models/'])
# [2025-12-11 15:51:52,217] [INFO] (root) - AppContext object: AppContext(input_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000, output_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0000, model_path=/home/anson/work/research-contributions/prostate-mri-lesion-seg/models, workdir=)
# [2025-12-11 15:51:52,217] [INFO] (app.AIProstateLesionSegApp) - App input and output path: /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000, /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0000
# [info] [gxf_executor.cpp:210] Creating context
# [warning] [gxf_extension_manager.cpp:132] Unable to load extension from 'libgxf_bayer_demosaic.so' (error: libnppicc.so.11: cannot open shared object file: No such file or directory)
# [info] [gxf_executor.cpp:1595] Loading extensions from configs...
# [info] [gxf_executor.cpp:1741] Activating Graph...
# [info] [gxf_executor.cpp:1771] Running Graph...
# [info] [gxf_executor.cpp:1773] Waiting for completion...
# [info] [gxf_executor.cpp:1774] Graph execution waiting. Fragment:
# [info] [greedy_scheduler.cpp:190] Scheduling 15 entities
# [2025-12-11 15:51:52,321] [INFO] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - No or invalid input path from the optional input port: None
# [2025-12-11 15:51:52,346] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-09.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,347] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-03.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,347] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-14.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,352] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-06.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,358] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-10.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,358] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-01.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,363] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-13.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,363] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-07.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,368] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-05.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,373] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-02.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,375] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-08.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,379] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-16.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,380] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-12.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,380] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-04.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,380] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-11.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,381] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/28.000000-tfldynfasttra1.5x1.5t3.5sec-85821/1-15.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,383] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-09.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,384] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-03.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,384] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-14.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,388] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-06.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,392] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-10.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,393] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-01.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,397] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-13.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,397] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-07.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,404] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-05.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,409] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-02.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,411] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-08.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,416] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-12.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,417] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-04.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,417] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-11.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,418] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/5.000000-t2tsecor-03471/1-15.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,420] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-09.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,420] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-03.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,421] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-14.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,425] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-06.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,430] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-10.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,431] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-01.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,435] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-13.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,435] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-07.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,440] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-05.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,444] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-02.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,446] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-08.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,450] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-16.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,451] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-12.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,451] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-04.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,451] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-11.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,452] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/23.000000-tfldynfasttra1.5x1.5t3.5sec-34844/1-15.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,454] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-09.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,454] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-03.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,455] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-14.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,458] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-06.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,464] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-10.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,464] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-01.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,467] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-13.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,468] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-07.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,473] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-05.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,478] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-02.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,479] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-08.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,483] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-16.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,483] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-12.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,483] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-04.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,484] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-11.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,484] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/49.000000-tfldynfasttra1.5x1.5t3.5sec-64782/1-15.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,486] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-09.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,486] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-03.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,487] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-14.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,490] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-06.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,495] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-10.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,496] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-01.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,499] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-13.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,499] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-07.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,505] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-05.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,508] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-02.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,509] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-08.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,513] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-16.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,513] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-12.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,513] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-04.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,514] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-11.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,514] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/21.000000-tfldynfasttra1.5x1.5t3.5sec-09542/1-15.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,516] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-09.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,516] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-03.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,516] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-14.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,520] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-06.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,525] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-10.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,525] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-01.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,528] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-13.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,529] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-07.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,534] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-05.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,804] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-02.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,809] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-08.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,815] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-16.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,816] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-12.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# [2025-12-11 15:51:52,816] [WARNING] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - Ignored /home/anson/work/research-contributions/prostate-mri-lesion-seg/test-data/ProstateX-0000/07-07-2011-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-05711/33.000000-tfldynfasttra1.5x1.5t3.5sec-21021/1-04.dcm:Zone.Identifier, reason being: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# ...
# [2025-12-11 15:52:46,106] [INFO] (root) -     Series attribute SeriesDescription value: t2_tse_sag
# [2025-12-11 15:52:46,106] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2025-12-11 15:52:46,106] [INFO] (root) - This series does not match the selection conditions.
# [2025-12-11 15:52:46,106] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.154156364083745277068656620138
# [2025-12-11 15:52:46,106] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2025-12-11 15:52:46,106] [INFO] (root) -     Series attribute Modality value: MR
# [2025-12-11 15:52:46,106] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
# [2025-12-11 15:52:46,106] [INFO] (root) -     Series attribute ImageType value: None
# [2025-12-11 15:52:46,106] [INFO] (root) - This series does not match the selection conditions.
# [2025-12-11 15:52:46,106] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.278358228783511961204087191158
# [2025-12-11 15:52:46,106] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2025-12-11 15:52:46,106] [INFO] (root) -     Series attribute Modality value: MR
# [2025-12-11 15:52:46,106] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
# [2025-12-11 15:52:46,106] [INFO] (root) -     Series attribute ImageType value: None
# [2025-12-11 15:52:46,106] [INFO] (root) - This series does not match the selection conditions.
# [2025-12-11 15:52:46,106] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.185507447168665319391310538903
# [2025-12-11 15:52:46,106] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2025-12-11 15:52:46,106] [INFO] (root) -     Series attribute Modality value: MR
# [2025-12-11 15:52:46,106] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
# [2025-12-11 15:52:46,106] [INFO] (root) -     Series attribute ImageType value: None
# [2025-12-11 15:52:46,106] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=AX T2)|(?=AX T2  6 NSA)|(?=AX T2  FAST)|(?=AX T2 . voxel 7x.8)|(?=AX T2 B1 Default)|(?=AX T2 CS)|(?=AX T2 cs 3.0)|(?=AX T2 FAST)|(?=AX T2 FRFSE)|(?=AX T2 N/S)|(?=AX T2 No sense)|(?=AX T2 NS)|(?=AX T2 NSA 3)|(?=AX T2 NSA 4)|(?=AX T2 NSA 5)|(?=AX T2 PROP)|(?=Ax T2 PROSTATE)|(?=AX T2 SMALL FOV)|(?=Ax T2 thin FRFSE)|(?=sT2 TSE ax no post)|(?=T2 AX)|(?=T2 AX SMALL FOV[*]? IF MOTION REPEAT[*]?)|(?=T2 AXIAL 3MM)|(?=T2 TRA 3mm)|(?=T2 TSE Ax)|(?=T2 TSE ax cs)|(?=T2 TSE ax hi)|(?=T2 TSE ax hi sense)|(?=T2 TSE ax no sense)|(?=T2 TSE ax NS)|(?=T2 TSE ax NSA 3)|(?=t2_tse_tra)|(?=t2_tse_tra_320_p2)|(?=t2_tse_tra_3mm _SFOV_TE 92)|(?=t2_tse_tra_Grappa3)|(?=T2W_TSE)|(?=T2W_TSE_ax)|(?=T2W_TSE_ax PSS Refoc 52)|(?=T2W_TSE_ax zoom PSS Refoc))'
# [2025-12-11 15:52:46,106] [INFO] (root) -     Series attribute SeriesDescription value: tfl_3d PD ref_tra_1.5x1.5_t3
# [2025-12-11 15:52:46,106] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2025-12-11 15:52:46,106] [INFO] (root) - This series does not match the selection conditions.
# [2025-12-11 15:52:46,106] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680
# [2025-12-11 15:52:46,107] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
# [2025-12-11 15:52:46,107] [INFO] (root) -     Series attribute Modality value: MR
# [2025-12-11 15:52:46,107] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
# [2025-12-11 15:52:46,107] [INFO] (root) -     Series attribute ImageType value: None
# [2025-12-11 15:52:46,107] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=AX T2)|(?=AX T2  6 NSA)|(?=AX T2  FAST)|(?=AX T2 . voxel 7x.8)|(?=AX T2 B1 Default)|(?=AX T2 CS)|(?=AX T2 cs 3.0)|(?=AX T2 FAST)|(?=AX T2 FRFSE)|(?=AX T2 N/S)|(?=AX T2 No sense)|(?=AX T2 NS)|(?=AX T2 NSA 3)|(?=AX T2 NSA 4)|(?=AX T2 NSA 5)|(?=AX T2 PROP)|(?=Ax T2 PROSTATE)|(?=AX T2 SMALL FOV)|(?=Ax T2 thin FRFSE)|(?=sT2 TSE ax no post)|(?=T2 AX)|(?=T2 AX SMALL FOV[*]? IF MOTION REPEAT[*]?)|(?=T2 AXIAL 3MM)|(?=T2 TRA 3mm)|(?=T2 TSE Ax)|(?=T2 TSE ax cs)|(?=T2 TSE ax hi)|(?=T2 TSE ax hi sense)|(?=T2 TSE ax no sense)|(?=T2 TSE ax NS)|(?=T2 TSE ax NSA 3)|(?=t2_tse_tra)|(?=t2_tse_tra_320_p2)|(?=t2_tse_tra_3mm _SFOV_TE 92)|(?=t2_tse_tra_Grappa3)|(?=T2W_TSE)|(?=T2W_TSE_ax)|(?=T2W_TSE_ax PSS Refoc 52)|(?=T2W_TSE_ax zoom PSS Refoc))'
# [2025-12-11 15:52:46,107] [INFO] (root) -     Series attribute SeriesDescription value: t2_tse_tra
# [2025-12-11 15:52:46,107] [INFO] (root) - Series attribute string value did not match. Try regEx.
# [2025-12-11 15:52:46,107] [INFO] (root) - Selected Series, UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680
# Beginning organ segmentation...
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Converted Image object metadata:
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680, type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesDate: 20111018, type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesTime: 115341.437000, type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Modality: MR, type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesDescription: t2_tse_tra, type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - PatientPosition: FFS, type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesNumber: 5, type <class 'int'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - row_pixel_spacing: 0.5, type <class 'float'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - col_pixel_spacing: 0.5, type <class 'float'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - depth_pixel_spacing: 4.244812427751082, type <class 'float'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - row_direction_cosine: [1.0, -1.99011e-10, 4.9619e-11], type <class 'list'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - col_direction_cosine: [2.051034e-10, 0.97029572703367, -0.2419218925608], type <class 'list'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - depth_direction_cosine: [1.4080733701821592e-17, 0.2419218925608, 0.97029572703367], type <class 'list'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - dicom_affine_transform: [[ 5.00000000e-01  1.02551700e-10  0.00000000e+00 -1.17913254e+02]
#  [-9.95055000e-11  4.85147864e-01  1.08864853e+00 -8.51499185e+01]
#  [ 2.48095000e-11 -1.20960946e-01  4.36633089e+00  1.28399916e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]], type <class 'numpy.ndarray'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - nifti_affine_transform: [[-5.00000000e-01 -1.02551700e-10 -0.00000000e+00  1.17913254e+02]
#  [ 9.95055000e-11 -4.85147864e-01 -1.08864853e+00  8.51499185e+01]
#  [ 2.48095000e-11 -1.20960946e-01  4.36633089e+00  1.28399916e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]], type <class 'numpy.ndarray'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.170561193612723093192571245493, type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyID: , type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyDate: 20111018, type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyTime: 113950.828000, type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyDescription: MR prostaat kanker detectie WDS_mc MCAPRODETW, type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - AccessionNumber: 1566645557835538, type <class 'str'>
# [2025-12-11 15:52:46,146] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - selection_name: t2, type <class 'str'>
# [2025-12-11 15:52:46,220] [INFO] (Loaded image) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([384, 384, 19])
# Value range: (0.0, 1432.0)
# [2025-12-11 15:52:46,221] [INFO] (Channel-first image) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([1, 384, 384, 19])
# Value range: (0.0, 1432.0)
# [2025-12-11 15:52:46,380] [INFO] (Resampled and normalized image) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([1, 192, 193, 82])
# Value range: (-1.5097216367721558, 6.934743404388428)
# [2025-12-11 15:52:48,835] [INFO] (Model output) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([3, 192, 193, 82])
# Value range: (0.21194157004356384, 0.5761168599128723)
# [2025-12-11 15:52:48,985] [INFO] (Inverted output) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([3, 384, 384, 19])
# Value range: (0.21194157004356384, 0.5761168599128723)
# [2025-12-11 15:52:48,991] [INFO] (AsDiscrete output) - Data statistics:
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
# Shape: torch.Size([1, 384, 384, 19])
# Value range: (0.0, 2.0)
# [2025-12-11 15:52:49,002] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Output Seg image numpy array shaped: (19, 384, 384)
# [2025-12-11 15:52:49,002] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Output Seg image pixel max value: 2
# 2025-12-11 15:52:49,024 INFO image_writer.py:197 - writing: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/t2/t2.nii.gz
# 2025-12-11 15:52:49,241 INFO image_writer.py:197 - writing: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/adc/adc.nii.gz
# 2025-12-11 15:52:49,268 INFO image_writer.py:197 - writing: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/highb/highb.nii.gz
# 2025-12-11 15:52:49,281 INFO image_writer.py:197 - writing: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/organ/organ.nii.gz
#
# Beginning lesion segmentation...
# Loading input...
# nda_resize_roi shape: (3, 215, 188, 170)
# Inputs shape: Inputs shape:  torch.Size([1, 3, 215, 188, 170])
#  torch.Size([1, 3, 215, 188, 170])
# Inputs shape:  torch.Size([1, 3, 215, 188, 170])
# Inputs shape:  torch.Size([1, 3, 215, 188, 170])
# Inputs shape:  torch.Size([1, 3, 215, 188, 170])
# Created file: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/lesion/fold4_lesion_prob.nii.gz
# Created file: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/lesion/fold3_lesion_prob.nii.gz
# Created file: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/lesion/fold2_lesion_prob.nii.gz
# Created file: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/lesion/fold1_lesion_prob.nii.gz
# Created file: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/lesion/fold0_lesion_prob.nii.gz
# nda_prob min: 0.0
# nda_prob max: 1.0691718862371773
# nda_prob mean: 0.003193199449499994
# nda_prob std: 0.05067162867498334
# [2025-12-11 15:52:59,996] [WARNING] (pydicom) - 'FileDataset.is_little_endian' will be removed in v4.0, set the Transfer Syntax UID or use the 'little_endian' argument with FileDataset.save_as() or dcmwrite() instead
# [2025-12-11 15:52:59,997] [WARNING] (pydicom) - 'FileDataset.is_implicit_VR' will be removed in v4.0, set the Transfer Syntax UID or use the 'implicit_vr' argument with FileDataset.save_as() or dcmwrite() instead
# Writing file to /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/organ/organ_RTSTRUCT.dcm
# [2025-12-11 15:53:00,083] [INFO] (root) - Organ RTSTRUCT created (multi-class): /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/organ/organ_RTSTRUCT.dcm
# [2025-12-11 15:53:00,125] [WARNING] (pydicom) - 'FileDataset.is_little_endian' will be removed in v4.0, set the Transfer Syntax UID or use the 'little_endian' argument with FileDataset.save_as() or dcmwrite() instead
# [2025-12-11 15:53:00,125] [WARNING] (pydicom) - 'FileDataset.is_implicit_VR' will be removed in v4.0, set the Transfer Syntax UID or use the 'implicit_vr' argument with FileDataset.save_as() or dcmwrite() instead
# Writing file to /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/lesion/lesion_RTSTRUCT.dcm
# [2025-12-11 15:53:00,250] [INFO] (root) - RTSTRUCT saved to: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/lesion/lesion_RTSTRUCT.dcm
# [2025-12-11 15:53:00,251] [INFO] (root) - Lesion RTSTRUCT created: /home/anson/work/research-contributions/prostate-mri-lesion-seg/output/ProstateX-0004/lesion/lesion_RTSTRUCT.dcm
# Beginning lesion classification...
# Loading images...
# Resampling ADC/HIGHB to match T2...
# Resampling all channels to (0.5, 0.5, 0.5)...
# Combined volume shape: torch.Size([4, 384, 384, 163])
# Inputs shape:  (384, 384, 163)
# nda_resize_crops shape:  (3, 3, 64, 64, 64)
# {'Organ': 'Prostate', 'Major_Axis_Length': 254.2433301214187, 'Volume': 22227.125}
# predicted_value: 1
# {'Lesion_ID': 1, 'Major_Axis_Length': 5.773502691896258, 'Volume': 15.75, 'PI_RADS': 3}
# predicted_value: 2
# {'Lesion_ID': 2, 'Major_Axis_Length': 11.528926617365215, 'Volume': 103.5, 'PI_RADS': 4}
# predicted_value: 1
# {'Lesion_ID': 3, 'Major_Axis_Length': 32.747865570919295, 'Volume': 8379.0, 'PI_RADS': 3}
# [info] [greedy_scheduler.cpp:369] Scheduler stopped: Some entities are waiting for execution, but there are no periodic or async entities to get out of the deadlock.
# [info] [greedy_scheduler.cpp:398] Scheduler finished.
# [info] [gxf_executor.cpp:1783] Graph execution deactivating. Fragment:
# [info] [gxf_executor.cpp:1784] Deactivating Graph...
# [info] [gxf_executor.cpp:1787] Graph execution finished. Fragment:
# [info] [gxf_executor.cpp:229] Destroying context
#
# real	0m28.848s
# user	0m43.525s
# sys	0m8.922s
# Batch processing complete.

# %% [markdown]
# Build the `lesion_seg_workflow_app` container, i.e., the MONAI Application Package (MAP). This may take more than 15 minutes during the initial build.

# %%
# Package code into MAP
APP_DIR="prostate_mri_lesion_seg_app"
MODEL_DIR=APP_DIR + "/models"
# !monai-deploy package $APP_DIR -l DEBUG -t lesion_seg_workflow_app -m $MODEL_DIR -c $APP_DIR/app.yaml --platform x64-workstation

# %%
# %%bash
#
# monai-deploy run lesion_seg_workflow_app-x64-workstation-dgpu-linux-amd64:1.0 -i test-data/ProstateX-0004/ -o output/
# Out:
# [2025-03-10 15:30:48,718] [INFO] (runner) - Checking dependencies...
# [2025-03-10 15:30:48,718] [INFO] (runner) - --> Verifying if "docker" is installed...
#
# [2025-03-10 15:30:48,718] [INFO] (runner) - --> Verifying if "docker-buildx" is installed...
#
# [2025-03-10 15:30:48,718] [INFO] (runner) - --> Verifying if "lesion_seg_workflow_app-x64-workstation-dgpu-linux-amd64:1.0" is available...
#
# [2025-03-10 15:30:48,745] [INFO] (runner) - Reading HAP/MAP manifest...
# e78bc1d0b1626d397f0a117855e31d21940746a6ed6179747baaaab9b200281f
# [2025-03-10 15:30:51,406] [INFO] (runner) - --> Verifying if "nvidia-ctk" is installed...
#
# [2025-03-10 15:30:51,406] [INFO] (runner) - --> Verifying "nvidia-ctk" version...
#
# [2025-03-10 15:30:53,579] [INFO] (common) - Launching container (3baab5796e76) using image 'lesion_seg_workflow_app-x64-workstation-dgpu-linux-amd64:1.0'...
#     container name:      nervous_dijkstra
#     host name:           8038Kidwell
#     network:             host
#     user:                1000:1000
#     ulimits:             memlock=-1:-1, stack=67108864:67108864
#     cap_add:             CAP_SYS_PTRACE
#     ipc mode:            host
#     shared memory size:  67108864
#     devices:
#     group_add:           44
# 2025-03-10 19:30:54 [INFO] Launching application python3 /opt/holoscan/app ...
#
# [info] [fragment.cpp:599] Loading extensions from configs...
#
# [info] [gxf_executor.cpp:264] Creating context
#
# [2025-03-10 19:30:56,858] [INFO] (root) - Parsed args: Namespace(log_level=None, input=None, output=None, model=None, workdir=None, argv=['/opt/holoscan/app'])
#
# [2025-03-10 19:30:56,860] [INFO] (root) - AppContext object: AppContext(input_path=/var/holoscan/input, output_path=/var/holoscan/output, model_path=/opt/holoscan/models, workdir=/var/holoscan)
#
# [2025-03-10 19:30:56,860] [INFO] (app.AIProstateLesionSegApp) - App input and output path: /var/holoscan/input, /var/holoscan/output
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'input_folder'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'dicom_study_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'dicom_study_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'dicom_study_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'study_selected_series_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'study_selected_series_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'study_selected_series_list'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_highb'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_organ_seg'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_adc'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_t2'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_lesion_seg'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_highb'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_organ_seg'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_adc'
#
# [info] [gxf_executor.cpp:1797] creating input IOSpec named 'image_t2'
#
# [info] [gxf_executor.cpp:2208] Activating Graph...
#
# [info] [gxf_executor.cpp:2238] Running Graph...
#
# [info] [gxf_executor.cpp:2240] Waiting for completion...
#
# [info] [greedy_scheduler.cpp:191] Scheduling 10 entities
#
# [2025-03-10 19:30:56,936] [INFO] (monai.deploy.operators.dicom_data_loader_operator.DICOMDataLoaderOperator) - No or invalid input path from the optional input port: None
#
# [2025-03-10 19:30:57,124] [INFO] (root) - Finding series for Selection named: highb
#
# [2025-03-10 19:30:57,124] [INFO] (root) - Searching study, : 1.3.6.1.4.1.14519.5.2.1.7311.5101.170561193612723093192571245493
#
#   # of series: 7
#
# [2025-03-10 19:30:57,124] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.212145009248667341607386363070
#
# [2025-03-10 19:30:57,124] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,124] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,124] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,124] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.473042633347744664896320600386
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.185507447168665319391310538903
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.278358228783511961204087191158
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.154156364083745277068656620138
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'TRACEW']
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,125] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=3B 2000 w ERC SSh_DWI)|(?=AX DIFFUSION_CALC_BVAL_DFC_MIX)|(?=AX DWI)|(?=.*AX DWI (50,1500).*)|(?=Ax DWI BH)|(?=AX DWI_TRACEW_DFC_MIX)|(?=Axial FOCUS DWI 1400)|(?=b_1500 prostate)|(?=b_2000 prostate)|(?=DIFF bv1400)|(?=diff tra b 50 500 800 WIP511b alle spoelenCALC_BVAL)|(?=diffusie-3Scan-4bval_fsCALC_BVAL)|(?=DW_Synthetic: Ax DWI All B-50-800 Synthetic B-1400)|(?=.*DW_Synthetic: Ax Focus 50,500,800,1400,2000.*)|(?=DWI PROSTATE)|(?=DWI_5b_0_1500)|(?=DWI_b2000)|(?=DWI_b2000_new)|(?=DWI_b2000_new SENSE)|(?=DWI_b2000_NSA6 SENSE)|(?=ep2d_diff_b1400_new 32 measipat)|(?=ep2d_diff_tra_DYNDIST_MIXCALC_BVAL$)|(?=ep2d_diff_tra_DYNDISTCALC_BVAL)|(?=ep2d_diff_tra2x2_Noise0_FS_DYNDISTCALC_BVAL)|(?=ep2d-advdiff-3Scan-high bvalue 1400)|(?=sb_1500)|(?=sb_2000)|(?=sB1400)|(?=sb1500)|(?=sb-1500)|(?=sb1500 r5 only)|(?=sb-2000)|(?=sDWI_b_2000)|(?=sDWI_b2000))'
#
# [2025-03-10 19:30:57,125] [INFO] (root) -     Series attribute SeriesDescription value: ep2d_diff_tra_DYNDIST_MIXCALC_BVAL
#
# [2025-03-10 19:30:57,125] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Selected Series, UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.154156364083745277068656620138
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Finding series for Selection named: adc
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Searching study, : 1.3.6.1.4.1.14519.5.2.1.7311.5101.170561193612723093192571245493
#
#   # of series: 7
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.212145009248667341607386363070
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'ADC']
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,126] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.473042633347744664896320600386
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'ADC']
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,126] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.185507447168665319391310538903
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'ADC']
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,126] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'ADC']
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,126] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.278358228783511961204087191158
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'ImageType' to match value: ['DIFFUSION', 'ADC']
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,126] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=ADC (10^-6 mm²/s))|(?=Apparent Diffusion Coefficient (mm2/s))|(?=AX DIFFUSION_ADC_DFC_MIX)|(?=.*AX DWI (50,1500)_ADC.*)|(?=AX DWI_ADC_DFC_MIX)|(?=b_1500 prostate_ADC)|(?=b_2000 prostate_ADC)|(?=d3B ADC 3B 750  ERC SSh_DWI FAST SENSE)|(?=dADC)|(?=dADC 0_1500)|(?=dADC 100 400 600)|(?=dADC 2)|(?=dADC 3)|(?=dADC ALL)|(?=dADC b 0 1000 2000)|(?=dADC from 0_1500)|(?=dADC from b0_600)|(?=dADC from B0-1500)|(?=dADC Map)|(?=dADC map 1)|(?=dADC MAP 2)|(?=dADC_1 axial)|(?=dADC_b375_750_1150)|(?=ddADC MAP)|(?=DIFF bv1400_ADC)|(?=diff tra b 50 500 800 WIP511b alle spoelen_ADC)|(?=diffusie-3Scan-4bval_fs_ADC)|(?=dReg - WIP SSh_DWI FAST SENSE)|(?=dSSh_DWI SENSE)|(?=DWI PROSTATE_ADC)|(?=dWIP 3B 600 w ERC SSh_DWI S2Ovs2)|(?=dWIP 3B ADC 3B 600 w/o ERC SSh_DWI FAST SENSE)|(?=dWIP SSh_DWI FAST SENSE)|(?=ep2d_diff_new 16 measipat_ADC)|(?=ep2d_DIFF_tra_b50_500_800_1400_alle_spoelen_ADC)|(?=ep2d_diff_tra_DYNDIST_ADC)|(?=ep2d_diff_tra_DYNDIST_MIX_ADC)|(?=ep2d_diff_tra2x2_Noise0_FS_DYNDIST_ADC)|(?=ep2d-advdiff-3Scan-4bval_spair_511b_ADC))'
#
# [2025-03-10 19:30:57,126] [INFO] (root) -     Series attribute SeriesDescription value: ep2d_diff_tra_DYNDIST_MIX_ADC
#
# [2025-03-10 19:30:57,126] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,127] [INFO] (root) - Selected Series, UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.278358228783511961204087191158
#
# [2025-03-10 19:30:57,127] [INFO] (root) - Finding series for Selection named: t2
#
# [2025-03-10 19:30:57,127] [INFO] (root) - Searching study, : 1.3.6.1.4.1.14519.5.2.1.7311.5101.170561193612723093192571245493
#
#   # of series: 7
#
# [2025-03-10 19:30:57,127] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.212145009248667341607386363070
#
# [2025-03-10 19:30:57,127] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,127] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,127] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
#
# [2025-03-10 19:30:57,127] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,127] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=AX T2)|(?=AX T2  6 NSA)|(?=AX T2  FAST)|(?=AX T2 . voxel 7x.8)|(?=AX T2 B1 Default)|(?=AX T2 CS)|(?=AX T2 cs 3.0)|(?=AX T2 FAST)|(?=AX T2 FRFSE)|(?=AX T2 N/S)|(?=AX T2 No sense)|(?=AX T2 NS)|(?=AX T2 NSA 3)|(?=AX T2 NSA 4)|(?=AX T2 NSA 5)|(?=AX T2 PROP)|(?=Ax T2 PROSTATE)|(?=AX T2 SMALL FOV)|(?=Ax T2 thin FRFSE)|(?=sT2 TSE ax no post)|(?=T2 AX)|(?=T2 AX SMALL FOV[*]? IF MOTION REPEAT[*]?)|(?=T2 AXIAL 3MM)|(?=T2 TRA 3mm)|(?=T2 TSE Ax)|(?=T2 TSE ax cs)|(?=T2 TSE ax hi)|(?=T2 TSE ax hi sense)|(?=T2 TSE ax no sense)|(?=T2 TSE ax NS)|(?=T2 TSE ax NSA 3)|(?=t2_tse_tra)|(?=t2_tse_tra_320_p2)|(?=t2_tse_tra_3mm _SFOV_TE 92)|(?=t2_tse_tra_Grappa3)|(?=T2W_TSE)|(?=T2W_TSE_ax)|(?=T2W_TSE_ax PSS Refoc 52)|(?=T2W_TSE_ax zoom PSS Refoc))'
#
# [2025-03-10 19:30:57,127] [INFO] (root) -     Series attribute SeriesDescription value: t2_tse_cor
#
# [2025-03-10 19:30:57,127] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.473042633347744664896320600386
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=AX T2)|(?=AX T2  6 NSA)|(?=AX T2  FAST)|(?=AX T2 . voxel 7x.8)|(?=AX T2 B1 Default)|(?=AX T2 CS)|(?=AX T2 cs 3.0)|(?=AX T2 FAST)|(?=AX T2 FRFSE)|(?=AX T2 N/S)|(?=AX T2 No sense)|(?=AX T2 NS)|(?=AX T2 NSA 3)|(?=AX T2 NSA 4)|(?=AX T2 NSA 5)|(?=AX T2 PROP)|(?=Ax T2 PROSTATE)|(?=AX T2 SMALL FOV)|(?=Ax T2 thin FRFSE)|(?=sT2 TSE ax no post)|(?=T2 AX)|(?=T2 AX SMALL FOV[*]? IF MOTION REPEAT[*]?)|(?=T2 AXIAL 3MM)|(?=T2 TRA 3mm)|(?=T2 TSE Ax)|(?=T2 TSE ax cs)|(?=T2 TSE ax hi)|(?=T2 TSE ax hi sense)|(?=T2 TSE ax no sense)|(?=T2 TSE ax NS)|(?=T2 TSE ax NSA 3)|(?=t2_tse_tra)|(?=t2_tse_tra_320_p2)|(?=t2_tse_tra_3mm _SFOV_TE 92)|(?=t2_tse_tra_Grappa3)|(?=T2W_TSE)|(?=T2W_TSE_ax)|(?=T2W_TSE_ax PSS Refoc 52)|(?=T2W_TSE_ax zoom PSS Refoc))'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute SeriesDescription value: t2_tse_sag
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.185507447168665319391310538903
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=AX T2)|(?=AX T2  6 NSA)|(?=AX T2  FAST)|(?=AX T2 . voxel 7x.8)|(?=AX T2 B1 Default)|(?=AX T2 CS)|(?=AX T2 cs 3.0)|(?=AX T2 FAST)|(?=AX T2 FRFSE)|(?=AX T2 N/S)|(?=AX T2 No sense)|(?=AX T2 NS)|(?=AX T2 NSA 3)|(?=AX T2 NSA 4)|(?=AX T2 NSA 5)|(?=AX T2 PROP)|(?=Ax T2 PROSTATE)|(?=AX T2 SMALL FOV)|(?=Ax T2 thin FRFSE)|(?=sT2 TSE ax no post)|(?=T2 AX)|(?=T2 AX SMALL FOV[*]? IF MOTION REPEAT[*]?)|(?=T2 AXIAL 3MM)|(?=T2 TRA 3mm)|(?=T2 TSE Ax)|(?=T2 TSE ax cs)|(?=T2 TSE ax hi)|(?=T2 TSE ax hi sense)|(?=T2 TSE ax no sense)|(?=T2 TSE ax NS)|(?=T2 TSE ax NSA 3)|(?=t2_tse_tra)|(?=t2_tse_tra_320_p2)|(?=t2_tse_tra_3mm _SFOV_TE 92)|(?=t2_tse_tra_Grappa3)|(?=T2W_TSE)|(?=T2W_TSE_ax)|(?=T2W_TSE_ax PSS Refoc 52)|(?=T2W_TSE_ax zoom PSS Refoc))'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute SeriesDescription value: tfl_3d PD ref_tra_1.5x1.5_t3
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - This series does not match the selection conditions.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Working on series, instance UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'Modality' to match value: 'MR'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute Modality value: MR
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'ImageType' to match value: ['ORIGINAL', 'PRIMARY']
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute ImageType value: None
#
# [2025-03-10 19:30:57,128] [INFO] (root) - On attribute: 'SeriesDescription' to match value: '((?=AX T2)|(?=AX T2  6 NSA)|(?=AX T2  FAST)|(?=AX T2 . voxel 7x.8)|(?=AX T2 B1 Default)|(?=AX T2 CS)|(?=AX T2 cs 3.0)|(?=AX T2 FAST)|(?=AX T2 FRFSE)|(?=AX T2 N/S)|(?=AX T2 No sense)|(?=AX T2 NS)|(?=AX T2 NSA 3)|(?=AX T2 NSA 4)|(?=AX T2 NSA 5)|(?=AX T2 PROP)|(?=Ax T2 PROSTATE)|(?=AX T2 SMALL FOV)|(?=Ax T2 thin FRFSE)|(?=sT2 TSE ax no post)|(?=T2 AX)|(?=T2 AX SMALL FOV[*]? IF MOTION REPEAT[*]?)|(?=T2 AXIAL 3MM)|(?=T2 TRA 3mm)|(?=T2 TSE Ax)|(?=T2 TSE ax cs)|(?=T2 TSE ax hi)|(?=T2 TSE ax hi sense)|(?=T2 TSE ax no sense)|(?=T2 TSE ax NS)|(?=T2 TSE ax NSA 3)|(?=t2_tse_tra)|(?=t2_tse_tra_320_p2)|(?=t2_tse_tra_3mm _SFOV_TE 92)|(?=t2_tse_tra_Grappa3)|(?=T2W_TSE)|(?=T2W_TSE_ax)|(?=T2W_TSE_ax PSS Refoc 52)|(?=T2W_TSE_ax zoom PSS Refoc))'
#
# [2025-03-10 19:30:57,128] [INFO] (root) -     Series attribute SeriesDescription value: t2_tse_tra
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Series attribute string value did not match. Try regEx.
#
# [2025-03-10 19:30:57,128] [INFO] (root) - Selected Series, UID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Converted Image object metadata:
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.206828891270520544417996275680, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesDate: 20111018, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesTime: 115341.437000, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Modality: MR, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesDescription: t2_tse_tra, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - PatientPosition: FFS, type <class 'str'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - SeriesNumber: 5, type <class 'int'>
#
# [2025-03-10 19:30:57,149] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - row_pixel_spacing: 0.5, type <class 'float'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - col_pixel_spacing: 0.5, type <class 'float'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - depth_pixel_spacing: 4.244812427751082, type <class 'float'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - row_direction_cosine: [1.0, -1.99011e-10, 4.9619e-11], type <class 'list'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - col_direction_cosine: [2.051034e-10, 0.97029572703367, -0.2419218925608], type <class 'list'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - depth_direction_cosine: [1.4080733701821592e-17, 0.2419218925608, 0.97029572703367], type <class 'list'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - dicom_affine_transform: [[ 5.00000000e-01  1.02551700e-10  0.00000000e+00 -1.17913254e+02]
#
#  [-9.95055000e-11  4.85147864e-01  1.08864853e+00 -8.51499185e+01]
#
#  [ 2.48095000e-11 -1.20960946e-01  4.36633089e+00  1.28399916e+01]
#
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]], type <class 'numpy.ndarray'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - nifti_affine_transform: [[-5.00000000e-01 -1.02551700e-10 -0.00000000e+00  1.17913254e+02]
#
#  [ 9.95055000e-11 -4.85147864e-01 -1.08864853e+00  8.51499185e+01]
#
#  [ 2.48095000e-11 -1.20960946e-01  4.36633089e+00  1.28399916e+01]
#
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]], type <class 'numpy.ndarray'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyInstanceUID: 1.3.6.1.4.1.14519.5.2.1.7311.5101.170561193612723093192571245493, type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyID: , type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyDate: 20111018, type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyTime: 113950.828000, type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - StudyDescription: MR prostaat kanker detectie WDS_mc MCAPRODETW, type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - AccessionNumber: 1566645557835538, type <class 'str'>
#
# [2025-03-10 19:30:57,150] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - selection_name: t2, type <class 'str'>
#
# [2025-03-10 19:30:57,160] [INFO] (Loaded image) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([384, 384, 19])
#
# Value range: (0.0, 1432.0)
#
# [2025-03-10 19:30:57,161] [INFO] (Channel-first image) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([1, 384, 384, 19])
#
# Value range: (0.0, 1432.0)
#
# [2025-03-10 19:30:57,276] [INFO] (Resampled and normalized image) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([1, 192, 193, 82])
#
# Value range: (-1.5097099542617798, 6.934730052947998)
#
# [2025-03-10 19:30:57,741] [INFO] (Model output) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([2, 192, 193, 82])
#
# Value range: (4.7445496420550626e-09, 1.0)
#
# [2025-03-10 19:30:57,858] [INFO] (Inverted output) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([2, 384, 384, 19])
#
# Value range: (2.0099241382354194e-08, 1.0)
#
# [2025-03-10 19:30:57,862] [INFO] (AsDiscrete output) - Data statistics:
#
# Type: <class 'monai.data.meta_tensor.MetaTensor'> torch.float32
#
# Shape: torch.Size([1, 384, 384, 19])
#
# Value range: (0.0, 1.0)
#
# [2025-03-10 19:30:57,868] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Output Seg image numpy array shaped: (19, 384, 384)
#
# [2025-03-10 19:30:57,868] [INFO] (monai.deploy.operators.monai_seg_inference_operator.MonaiSegInferenceOperator) - Output Seg image pixel max value: 1
#
#
#
# Beginning organ segmentation...
#
# 2025-03-10 19:30:57,875 INFO image_writer.py:197 - writing: /var/holoscan/output/t2/t2.nii.gz
#
# 2025-03-10 19:30:57,999 INFO image_writer.py:197 - writing: /var/holoscan/output/adc/adc.nii.gz
#
# 2025-03-10 19:30:58,008 INFO image_writer.py:197 - writing: /var/holoscan/output/highb/highb.nii.gz
#
# 2025-03-10 19:30:58,015 INFO image_writer.py:197 - writing: /var/holoscan/output/organ/organ.nii.gz
#
#
#
# Beginning lesion segmentation...
#
# Loading input...
#
# [info] [greedy_scheduler.cpp:372] Scheduler stopped: Some entities are waiting for execution, but there are no periodic or async entities to get out of the deadlock.
#
# [info] [greedy_scheduler.cpp:401] Scheduler finished.
#
# [info] [gxf_executor.cpp:2243] Deactivating Graph...
#
# [info] [gxf_executor.cpp:2251] Graph execution finished.
#
# [info] [gxf_executor.cpp:294] Destroying context
#
# Inputs shape:  torch.Size([1, 3, 206, 186, 170])
#
# Inputs shape:  torch.Size([1, 3, 206, 186, 170])
#
# Inputs shape:  torch.Size([1, 3, 206, 186, 170])
#
# Inputs shape:  torch.Size([1, 3, 206, 186, 170])
#
# Inputs shape:  torch.Size([1, 3, 206, 186, 170])
#
# Created file: /var/holoscan/output/lesion/fold1_lesion_prob.nii.gz
#
# Created file: /var/holoscan/output/lesion/fold0_lesion_prob.nii.gz
#
# Created file: /var/holoscan/output/lesion/fold3_lesion_prob.nii.gz
#
# Created file: /var/holoscan/output/lesion/fold4_lesion_prob.nii.gz
#
# Created file: /var/holoscan/output/lesion/fold2_lesion_prob.nii.gz
#
# nda_prob min: 0.0
#
# nda_prob max: 1.0
#
# nda_prob mean: 0.003159677765710894
#
# nda_prob std: 0.05078099335586837
#
#
#
# Beginning lesion classification...
#
# Loading images...
#
# Resampling ADC/HIGHB to match T2...
#
# Resampling all channels to (0.5, 0.5, 0.5)...
#
# Combined volume shape: torch.Size([4, 384, 384, 163])
#
# Inputs shape:  (384, 384, 163)
#
# nda_resize_crops shape:  torch.Size([3, 64, 64, 64])
#
# {'Organ': 'Prostate', 'Major_Axis_Length': 253.97388926871932, 'Volume': 17872.75}
#
# predicted_value: 1
#
# {'Lesion_ID': 1, 'Major_Axis_Length': 32.67513188512687, 'Volume': 8581.5, 'PI_RADS': 3}
# [2025-03-10 15:31:18,706] [INFO] (common) - Container 'nervous_dijkstra'(3baab5796e76) exited.

# %%
# Load and display the output nifti segmentation on top of the t2 image
import os
import nibabel as nib
import matplotlib.pyplot as plt

t2_img = nib.load(os.path.join("output", "ProstateX-0004/t2/t2.nii.gz"))
organ_seg = nib.load(os.path.join("output", "ProstateX-0004/organ/organ.nii.gz"))
lesion_seg = nib.load(os.path.join("output", "ProstateX-0004/lesion/lesion_mask.nii.gz"))

t2_data = t2_img.get_fdata()
organ_data = organ_seg.get_fdata()
lesion_data = lesion_seg.get_fdata()

# Plot the t2 image, organ segmentation and lesion segmentation
slice = t2_data.shape[2] // 2
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.imshow(t2_data[:, :, slice].T, cmap="gray")
plt.title("T2 Image")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(organ_data[:, :, slice].T, cmap="gray")
plt.title("Organ Segmentation")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(lesion_data[:, :, slice].T, cmap="gray")
plt.title("Lesion Segmentation")
plt.axis("off")

plt.show()

# Create a single image with all the segmentations
plt.figure(figsize=(5, 5))
plt.imshow(t2_data[:, :, slice].T, cmap="gray")
plt.imshow(organ_data[:, :, slice].T, cmap="jet", alpha=0.5)
plt.imshow(lesion_data[:, :, slice].T, cmap="jet", alpha=0.5)
plt.title("T2 Image with Organ and Lesion Segmentations")
plt.axis("off")
plt.show()
