# %%
from scripts.fill_series_description_template import fill_series_description

fill_series_description(
    test_data_root="/mnt/d/Anson/sgh de-id data comprehensive",
    output_path="series_description_sgh_deid_data_hahaha.csv",
    app_path="prostate_mri_lesion_seg_app/app.py",
    num_workers=8,
)
# Out:
# Auto-discovered 3538 case(s) in /mnt/d/Anson/sgh de-id data comprehensive/
# Cases to process: 3538
# Cases:   0%|          | 0/3538 [00:00<?, ?case/s]/home/anson/.pyenv/versions/3.11.11/lib/python3.11/site-packages/pydicom/valuerep.py:440: UserWarning: The value length (20) exceeds the maximum length of 16 allowed for VR SH.
#   warn_and_log(msg)
# Cases:   0%|          | 3/3538 [00:02<49:37,  1.19case/s], errors=0, series=2
# Interrupted — finishing in-progress cases, then stopping...
# (Press Ctrl+C again to force quit immediately)
#
#
# ============================================================
# Processed  : 2 case(s), 2 series
# Elapsed    : 0m02s
# Output     : series_description_sgh_deid_data_hahaha.csv
#
# Remaining  : 3536 case(s) — re-run to resume.
# ============================================================
# 'series_description_sgh_deid_data_hahaha.csv'
